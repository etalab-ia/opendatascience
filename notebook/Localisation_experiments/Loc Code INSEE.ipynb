# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
#Sklearn
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE

#other
import concurrent.futures
import time
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline

# Plotly 
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff

#spaCy
import spacy
nlp = spacy.load("fr_core_news_lg")
from spacy.lang.fr.stop_words import STOP_WORDS
from spacy.lang.fr import French
import string
punctuations = string.punctuation
stopwords = list(STOP_WORDS)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Load (acceptably clean) data

# %%
data=pd.read_pickle("../../data/cleaned2.pkl")
data_np=data.to_numpy()

# %%
data=np.load('../../data/organizations_col.npy', allow_pickle=True)

# %%
data_single=list(dict.fromkeys(data))

# %%
data_single=[x for x in data_single if str(x) != 'nan']

# %%
len(data_single)
# Out:
# 1161

# %%
i=random.randint(1, 1161)
data_single[i]
# Out:
# "Commune d'Eguisheim"

# %%
import progressbar
bar = progressbar.ProgressBar(maxval=len(data_np), \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])

# %% [markdown]
# ## Process data to extract keywords only

# %% [markdown]
# ### Extract the locs

# %%
def extract_locs(doc):
    all_locs=[None]*len(doc)
    bar.start()
    for i in range(len(doc)):
        this_doc=[]
        for token in nlp(doc[i]):
            if token.ent_type_=='LOC':
                this_doc.append(token.text)
        all_locs[i]=this_doc
        bar.update(i+1)
    bar.finish()
    return(all_locs)

import unicodedata
def strip_accents(text):

    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")

    return str(text)

# %%
all_locs=extract_locs(data_single)
# Out:
# [========================================================================] 100%

# %%
all_locs
# Out:
# [['Paris'],
#  ['Chambéry'],
#  ['Corse'],
#  ['Orléans', 'Métropole'],
#  ['Saint-Denis', 'La', 'Réunion'],
#  ['Réseau', ' ', 'régional', 'Inspection'],
#  [],
#  ['Gamarthe'],
#  ['Île-de-France'],
#  [],
#  ['Paris', 'Seine', 'Ouest'],
#  [],
#  [],
#  ['Antibes'],
#  [],
#  ['Département', 'de', 'Loire', 'Atlantique'],
#  ['Région', 'Île-de-France'],
#  ['Région', 'Centre', 'Val', 'de', 'Loire'],
#  ['Département', 'de', "l'", 'Hérault'],
#  ['Haute-Garonne'],
#  [],
#  ['Eurométropole', 'de', 'Strasbourg'],
#  ['Département', 'du', 'Doubs'],
#  ['Métropole', 'Nice'],
#  [],
#  ['Saint-Claude'],
#  [],
#  ['Nantes', 'Métropole'],
#  [],
#  [],
#  [],
#  ['Région', 'Reunion'],
#  ['France'],
#  ['Française'],
#  [],
#  ['Syndicat', 'Mixte', 'des', 'Stations', 'du', 'Mercantour'],
#  [],
#  ['Tours', 'Métropole', 'Val', 'de', 'Loire'],
#  ['Ville', 'de', 'Saint-Egrève'],
#  ['Région', 'Provence', 'Alpes', 'Côte', 'Azur'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', "d'", 'agglomération', 'du', 'Val', 'de', 'Fensch'],
#  [],
#  ['Bourgogne', 'Franche', 'Comté'],
#  [],
#  [],
#  [],
#  ['Toulouse'],
#  [],
#  ['Ville', 'de', 'Pontault', 'Combault'],
#  ['Région', 'Hauts-de-France'],
#  ['Communauté', "d'", 'agglomération', 'de', 'la', 'région', 'nazairienne'],
#  [],
#  ['Issy-les-Moulineaux'],
#  [],
#  ['Affaires', 'Etrangères'],
#  [],
#  ['Madada'],
#  [],
#  ['Oise'],
#  [],
#  ['Mégalis', 'Bretagne'],
#  ['Région', 'Occitanie', 'Pyrénées', 'Méditerranée'],
#  [],
#  ['Atlasanté'],
#  ['Département', 'des', 'Hautes-Pyrénées'],
#  ['Nantes'],
#  ['Evron'],
#  [],
#  ['Grand', 'Chalon'],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Pays', 'de', 'Saint-Omer'],
#  [],
#  ['Ville', 'de', 'Besancon'],
#  [],
#  [],
#  ['Garges-lès-Gonesse'],
#  ['Département', 'des', 'Côtes', "d'", 'Armor'],
#  ['Roubaix'],
#  [],
#  [],
#  [],
#  ['Région', 'Bretagne'],
#  [],
#  ['Communauté', 'de', 'communes', 'Quercy', 'Vert', 'Aveyron'],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  ['Bar-le-Duc'],
#  ['Parc', 'naturel', 'régional', 'des', 'Vosges', 'du', 'Nord'],
#  [],
#  [],
#  ['Provence', 'Alpes', 'Côte', "d'", 'Azur'],
#  [],
#  ['Agen'],
#  [],
#  ['Pays', 'de', 'Châteaugiron', 'Communauté'],
#  [],
#  ['Aire', 'Grenobloise'],
#  ['Fédération', 'des', 'Parcs', 'Naturels'],
#  ['Eure-et-Loir'],
#  ['Marseille'],
#  ['Département', 'du', 'Bas-Rhin'],
#  ['Départemental', 'Pyrénées', 'Orientales'],
#  ['Seine-Saint-Denis', 'Département'],
#  [],
#  [],
#  ['Métropole', 'Européenne', 'de', 'Lille'],
#  [],
#  ['Grenoble', 'Alpes', 'Métropole'],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Saint-Quentinois'],
#  [],
#  [],
#  [],
#  [],
#  ['Département', 'de', 'Maine-et-Loire'],
#  [],
#  ['Angers', 'Loire', 'Métropole'],
#  ['Montesquieu', 'Volvestre'],
#  ['e-Totem'],
#  ['Région', 'des', 'Pays', 'de', 'la', 'Loire'],
#  [],
#  ['Français'],
#  ['Coaching', 'Lille'],
#  [],
#  ['Gisaïa'],
#  [],
#  [],
#  [],
#  [],
#  ['Cerema'],
#  [],
#  ['Ewolis'],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'de', 'Nevers'],
#  ['Mulhouse'],
#  [],
#  [],
#  ['Rennes', 'Métropole'],
#  [],
#  ['Saint-Étienne-de-Baïgorry'],
#  [],
#  ['Grand', 'Est'],
#  ['Bois-le'],
#  [],
#  [],
#  ['Mont', 'de', 'Marsan'],
#  [],
#  ['Alpes', 'Maritimes'],
#  ['Kalisio'],
#  ['Lacarre'],
#  ['Hauts-de-Seine', 'Département'],
#  [],
#  [],
#  ['Ville', 'de', 'Noisiel'],
#  ['Grenoble'],
#  ['Digne-les-Bains'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'du', 'Rhône'],
#  [],
#  ['Région', 'Normandie'],
#  [],
#  ['Bergerac'],
#  ['IdeesLibres.org'],
#  ['Çaro'],
#  [],
#  [],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'du', 'Doubs'],
#  ['Communauté', "d'", 'agglomération', 'Paris', 'Vallée', 'de', 'la', 'Marne'],
#  ['Bordeaux', 'Métropole'],
#  [],
#  ['Ville', 'de', 'Nanterre'],
#  ['Communauté', 'de', 'communes', 'du', 'Pays', 'Mornantais'],
#  ['Organisation', 'Urbaine', 'du', 'Valenciennois'],
#  [],
#  [],
#  ['Montbéliard'],
#  [],
#  ['Jaxu'],
#  [],
#  [],
#  ['Nouvelle'],
#  [],
#  [],
#  ['Ville', 'de', 'Caen'],
#  ['Anglet'],
#  [],
#  ['Champagne-sur-Seine'],
#  [],
#  [],
#  [],
#  ['HERAULT'],
#  [],
#  [],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'de',
#   'Meurthe-et-Moselle'],
#  ['Interdépartemental', ' ', 'De', "l'", 'Eau', 'Seine', 'Aval'],
#  [],
#  ['Département', 'de', "l'", 'Indre'],
#  ['Ville', 'Châtellerault'],
#  ['Châtellerault'],
#  [],
#  ['Cerema', 'Pôle'],
#  [],
#  ['Cap', 'Atlantique'],
#  [],
#  [],
#  [],
#  ['Métropole', 'de', 'Lyon'],
#  ['Communauté', 'urbaine', 'de', 'Caen'],
#  ['Communauté', "d'", 'Agglomération', 'de', 'Grand', 'Chatellerault'],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Département', 'du', 'Calvados'],
#  ['Département', 'du', 'Gers'],
#  ['Communauté',
#   "d'",
#   'Agglomération',
#   'de',
#   'la',
#   'Région',
#   'de',
#   'Compiègne',
#   'Basse',
#   'Automne'],
#  [],
#  [],
#  [],
#  ['Louvre', 'Lens', 'France'],
#  [],
#  [],
#  [],
#  ['Châteaugiron'],
#  [],
#  ['Phramboise'],
#  ['SICAE', 'OISE'],
#  ['Département', 'du', 'Loiret'],
#  ['ANDUZE'],
#  [],
#  [],
#  ['Rambouillet'],
#  [],
#  ['Périgny'],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Grand', 'Dole'],
#  ['DECAZEVILLE'],
#  ['Bibliothèque', 'nationale', 'de', 'France'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'des',
#   'Alpes',
#   'de',
#   'Haute-Provence'],
#  [],
#  [],
#  [],
#  ['Indre-et-Loire'],
#  [],
#  [],
#  ['Pays', 'de', 'la', 'Loire'],
#  [],
#  ['La', 'Rochelle'],
#  ['Communauté', 'de', 'Communes', 'du', 'Trièves'],
#  [],
#  ["L'", 'AUBOIS'],
#  ['Communauté', 'de', 'communes', 'du', 'val', 'de', 'Drôme', 'Biovallée'],
#  [],
#  ['France'],
#  ['Belfort', 'Communauté', "d'", 'Agglomération'],
#  [],
#  [],
#  ['Ile', 'de', 'Ré'],
#  [],
#  ['Roissy-en-Brie'],
#  ['Grand', 'Narbonne', 'Communauté', "d'", 'Agglomération'],
#  ['Nice'],
#  [],
#  ['Béthune'],
#  [],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Saint-Marcel'],
#  ['Saint-Esteben'],
#  ['Communauté', "d'", 'Agglomération'],
#  ['La', 'Grande', 'Paroisse'],
#  ['Sixt-sur-Aff'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'des', 'Vosges'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'Atlantique'],
#  ['Lorient'],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  ['Ville', 'de', 'Quiberon'],
#  ['Parc', 'Naturel', 'régional', 'de', 'la', 'Montagne', 'de', 'Reims'],
#  ['Communauté', 'de', 'communes', 'du', 'Frontonnais'],
#  [],
#  [],
#  [],
#  ['Syndicat', 'Mixte', 'Alpes', 'Cote', "d'", 'Azur'],
#  ['Ville', 'de', 'Pirae'],
#  [],
#  [],
#  [],
#  ['Communauté', 'de', 'Communes', 'du', 'Plateau', 'picard'],
#  ['Itxassou'],
#  [],
#  ['Communauté', 'de', 'Communes', 'de', 'Forez', 'Est'],
#  ['Communauté', 'de', 'Communes', 'du', 'Centre', 'Haut-Rhin'],
#  ['Ainhoa'],
#  [],
#  ['Nancy'],
#  ['Communauté', 'de', 'Communes', 'Lacs', 'Gorges', 'du', 'Verdon'],
#  [],
#  [],
#  ['Communauté',
#   'de',
#   'communes',
#   'de',
#   'la',
#   'porte',
#   'des',
#   'Vosges',
#   'Méridionales'],
#  [],
#  ['Côtes', "d'", 'Armor'],
#  ['Oise'],
#  [],
#  [],
#  ['Département', 'du', 'Morbihan'],
#  ['Saint-Vincent-sur-Oust'],
#  ['Communauté', 'de', 'Communes', 'du', 'Pays', 'Réuni', "d'", 'Orange'],
#  ['Communauté', 'de', 'communes', 'Alpilles'],
#  ['Syndicat', 'Mixte', 'Communautés', 'de', 'communes'],
#  [],
#  [],
#  [],
#  [],
#  ['Boé'],
#  ['Région', 'Réunion'],
#  ['Saint-Etienne', 'Métropole'],
#  ['Département', "d'", 'Ille-et-Vilaine'],
#  [],
#  [],
#  [],
#  [],
#  ['Drôme'],
#  ['Montluçon', 'Communauté'],
#  ['Pays', 'de', 'Brest'],
#  ['Le', 'Havre', 'Seine', 'Métropole'],
#  [],
#  [],
#  [],
#  ['Boulogne', 'Billancourt'],
#  ['FranceAgriMer'],
#  ['Yanport'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'du', 'Cher'],
#  [],
#  ['Dombrot', 'Vair'],
#  ['Antony'],
#  [],
#  ['Les', 'Lilas'],
#  [],
#  ['Essonne'],
#  ['Filibus', 'Chartres', 'Métropole', 'Transports'],
#  ['Avignon'],
#  ["D'", 'ETAPLES', 'MER'],
#  ['Adour'],
#  ['Chalons', 'Champagne'],
#  [],
#  [],
#  ['Saint-Paul-lès-Dax'],
#  ["Côte-d'Or"],
#  ['Hautes-Pyrénées'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'Seine-et-Marne'],
#  ['Pau', 'Béarn'],
#  ['Communauté', "d'", 'agglomération', 'de', "l'", 'Albigeois'],
#  [],
#  ['Levallois'],
#  ['lycée', 'Dumont'],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Grand', 'Cahors'],
#  [],
#  ['Rillieux'],
#  ['Firminy'],
#  [],
#  [],
#  [],
#  [],
#  ['Saint-Germain-en-Laye'],
#  ['Mixte', 'Interdépartemental'],
#  [],
#  [],
#  [],
#  ['Communauté', "d'", 'agglomération', 'du', 'grand', 'Gueret'],
#  ['Bordeaux', 'Euratlantique'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Brocas'],
#  [],
#  [],
#  ['Communauté', 'de', 'Communes', 'du', 'Golfe', 'de', 'Saint-Tropez'],
#  ['Osserain', 'Rivareyte'],
#  ['Ayherre'],
#  ['Lisieux'],
#  ['Morbihan', 'Tourisme'],
#  ['Bains-sur-Oust'],
#  [],
#  ['Atoumod'],
#  ['Aeroport', 'Paris', 'Beauvais', 'SAGEB'],
#  [],
#  ['org', 'testmarc'],
#  [],
#  ['LAMASTRE'],
#  ['Conseil', 'Départemental', 'Mayenne'],
#  [],
#  [],
#  [],
#  ['Région', 'GRAND', 'EST'],
#  ['Val', 'de', 'Saône'],
#  [],
#  ['Syndicat', 'Mixte', 'du', 'Bassin', "d'", 'Alès'],
#  ['Vbus', 'Communauté', "d'", 'Agglomération', 'de', 'Vesoul'],
#  [],
#  ['Métropole', 'Rouen', 'Normandie'],
#  [],
#  ['Villiers-le-Bel'],
#  [],
#  [],
#  [],
#  ['GUILLESTRE'],
#  ['Aiguillon', 'Construction'],
#  [],
#  ['Arles', 'Crau', 'Camargue', 'Montagnette'],
#  [],
#  ['WYZY'],
#  [],
#  ['Communauté', 'de', 'Communes', 'du', 'Volvestre'],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  [],
#  ['SPL', 'Horizon', 'Réunion'],
#  ['Morbihan'],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Bassin', 'de', 'Brive'],
#  ['Plessis-Trévise'],
#  ['Val', 'de', 'Loire'],
#  ['Saint-Loubès'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Shom'],
#  ['Communauté', 'de', 'communes', 'du', 'Pays', 'Bigouden', 'Sud'],
#  ['Ardennes'],
#  ['Ille-et-Vilaine'],
#  ['Manche'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'la', 'Sarthe'],
#  ['Port', 'Maritime', 'de', 'la', 'Guadeloupe'],
#  ['Communauté', "d'", 'Agglomération', 'du', 'Pays', 'Ajaccien'],
#  [],
#  ['Pleumeleuc'],
#  [],
#  ['Courcuire'],
#  ['CASTRES', 'MAZAMET'],
#  ['Communauté', 'de', 'Communes', 'Coeur', "d'", 'Ostrevent'],
#  [],
#  ['Communauté', 'de', 'communes'],
#  [],
#  [],
#  [],
#  ['Communauté', 'de', 'Communes', 'Beaucaire'],
#  [],
#  ['nam', 'R'],
#  [],
#  [],
#  ['Métropole', 'Grand', 'Nancy'],
#  [],
#  ['Saint-Just-Luzac'],
#  ['Montendre'],
#  ['Dolus', "d'", 'Oléron'],
#  ['Saint-Palais-sur-Mer'],
#  ['La', 'Tremblade'],
#  ['CENTRE'],
#  ['Saint-Brieuc'],
#  ['Communauté', 'de', 'Communes', 'des', 'Sources', 'de', "l'", 'Orne'],
#  [],
#  ['Département', 'de', 'Saône-et-Loire'],
#  ['delta', 'du', 'Rhône'],
#  [],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  ['Paris'],
#  [],
#  [],
#  ['Bassin', 'de', 'Pompey'],
#  [],
#  ['Doué-en-Anjou'],
#  ['France'],
#  ['Eguisheim'],
#  ['CERTEUROPE', 'OMNIKLES'],
#  ['La', 'Croix', 'en', 'Touraine'],
#  [],
#  ['Tullins'],
#  [],
#  [],
#  ['Parisien'],
#  [],
#  ['Alto'],
#  [],
#  [],
#  ['Saint-Bonnet-le-Bourg'],
#  [],
#  ['Côte', 'Ouest'],
#  [],
#  [],
#  [],
#  ['DE', 'SAINT', 'CYR', 'SUR', 'MER'],
#  ['Ganges'],
#  ['Agglomération', 'Montargoise'],
#  ['Communauté', "d'", 'agglomération'],
#  [],
#  ['de', "l'", 'Isère'],
#  ['Maubeuge'],
#  ['Wambrechies'],
#  ['Metz', 'Métropole'],
#  [],
#  [],
#  [],
#  [],
#  ['Nouvelle', 'Aquitaine'],
#  [],
#  ['Autunois'],
#  [],
#  ['Parc', 'national', 'du', 'Mercantour'],
#  ["Transp'", 'Or', 'Pays', 'de', "l'", 'Or', 'Agglomération'],
#  ['Beaufort-en-Anjou'],
#  [],
#  ['Eze'],
#  ['Infolocale'],
#  [],
#  ['Montpellier', 'Méditerranée'],
#  ['Neuilly', 'sur', 'Marne'],
#  [],
#  ['Dammartin-en-Goële'],
#  [],
#  [],
#  ['Optymo', 'Belfort'],
#  [],
#  ['Communauté',
#   "d'",
#   'Agglomération',
#   'de',
#   'la',
#   'Région',
#   'Dieppoise',
#   'Dieppe',
#   'Maritime'],
#  ['Communauté', 'de', 'communes', 'de', 'la', 'Terre'],
#  ['Lampertheim'],
#  ['Département', 'de', 'l\x92Aisne'],
#  [],
#  [],
#  ['OpenEventDatabase'],
#  [],
#  ['Seine-et-Marne'],
#  ['Avicca'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'de',
#   "l'",
#   'Eure'],
#  ['Pyrénées', 'Orientales'],
#  ['Vendée'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'Haute-Savoie'],
#  ['Communauté', 'Urbaine', 'de', 'Dunkerque'],
#  ['RITMO', 'Communauté', "d'", 'agglomération', 'de', 'Haguenau'],
#  [],
#  ['Grand-Orly', 'Seine', 'Bièvre'],
#  ['Chambre', "d'", 'agriculture', 'de', 'la', 'Haute-Garonne'],
#  ['Mâconnais', 'Beaujolais'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', "l'", 'Ariège'],
#  ['Direction', 'Départementale', 'des', 'Territoires', "d'", 'Eure-et-Loir'],
#  [],
#  ['Champoux'],
#  [],
#  ['TCAT'],
#  ['Draguignan'],
#  [],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Tallis'],
#  ['SMAEP'],
#  ['Ville', 'de', 'Saint-Avé'],
#  [],
#  [],
#  ['Forestière'],
#  ['Intercommunal', 'de', 'Transport'],
#  [],
#  ['Fédération', 'Départementale', "d'", 'Energie', 'de', 'la', 'Somme'],
#  ['Parc', 'national', 'des', 'Écrins'],
#  ['mer', 'du', 'Nord'],
#  ['Communauté', "d'", 'Agglomération', 'Sud'],
#  [],
#  [],
#  ['GéoCompiégnois'],
#  ['Onet-le-Château'],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'de', "l'", 'Auxerrois'],
#  ['Sartrouville'],
#  ['Rosny-sous-Bois'],
#  [],
#  ['Sète', 'Agglopole', 'Méditerranée'],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', 'de', 'communes', 'du', 'Grand', 'Chambord'],
#  ['Mont-près-Chambord'],
#  ['Saint-Laurent-Nouan'],
#  [],
#  [],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Parc', 'national', 'des', 'Cévennes'],
#  ['Herrlisheim'],
#  ['Communauté', 'de', 'communes', 'du', 'Pays', 'Rhénan'],
#  ['Ulis'],
#  ['Communauté', "d'", 'agglomération', 'de', 'La', 'Rochelle'],
#  ['Château-Renault'],
#  ['Quimper', 'Bretagne', 'Occidentale'],
#  ['Bron'],
#  [],
#  [],
#  ['FOIX', 'VARILHES'],
#  ['Communauté', 'de', 'Communes', 'Sarrebourg', 'Moselle', 'Sud'],
#  ['Ville', 'Vierzon'],
#  [],
#  [],
#  ['Syndicat', 'Mixte', 'SCoT', 'de', 'la', 'Haute', 'Blaye', 'Estuaire'],
#  ['Maisons', 'Cites'],
#  ['Mazingarbe'],
#  ['Caudry'],
#  [],
#  [],
#  ['Communauté', 'de', 'Communes', 'de', 'la', 'Plaine', 'Jurassienne'],
#  [],
#  [],
#  [],
#  [],
#  ['Nogent-sur-Marne'],
#  [],
#  ['Ville', 'de', 'Nevers'],
#  ['Finances', 'Hauts-de-Seine'],
#  [],
#  ['Communauté', "d'", 'agglomération', 'du', 'Pays', 'de', 'Grasse'],
#  ['Transfermuga', 'Eurorégion', 'Aquitaine'],
#  [],
#  [],
#  ['Pays', 'de', 'la', 'Haute', 'Gironde'],
#  ['DE', 'FONTENOY', 'LE', 'CHATEAU'],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  ['Communauté', 'de', 'communes', 'Vallée', 'de', 'la', 'Dordogne'],
#  ['Communauté', "d'", 'Agglomération', 'Saint-Lô', 'Agglo'],
#  ['Durance', 'Luberon', 'Verdon', 'Agglomération'],
#  [],
#  ['Gaude'],
#  ['Public', 'Médico-Social', "d'", 'Amiens'],
#  [],
#  ['Territoires', 'Numériques', 'Franche', 'Comté'],
#  ['Fédération', 'Française', 'de', 'Vol', 'Libre'],
#  ['Longjumeau'],
#  [],
#  ['Industrie', 'Numérique'],
#  ['Autun'],
#  ['Venelles'],
#  [],
#  ['Communauté', 'Urbaine', 'du', 'Grand', 'Reims'],
#  [],
#  ['Syndicat', 'Mixte', 'de', "l'", 'Argens'],
#  ['Fégréac'],
#  [],
#  [],
#  ['Centre', 'Pompidou', 'Metz'],
#  ['Klekoon'],
#  ['Chalons'],
#  [],
#  ['Musée', "d'", 'art', 'et', "d'", 'histoire', 'Ville', 'Saint-Brieuc'],
#  [],
#  [],
#  [],
#  ['TALENSAC'],
#  ['Cogolin'],
#  ['Montfort', 'Communauté'],
#  ['Communauté', "d'", 'Agglomération'],
#  [],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Saint-Maurice-de-Beynost'],
#  ['Manche', 'Habitat'],
#  [],
#  [],
#  ['Airparif'],
#  [],
#  [],
#  [],
#  ['Laimont'],
#  ['Communauté', "d'", 'Agglomération', 'de', 'Melun', 'Val', 'de', 'Seine'],
#  [],
#  ['Picardie'],
#  ['Petit-Couronne'],
#  [],
#  ['Sainte-Marie'],
#  ['Guémené', 'Penfao'],
#  [],
#  [],
#  ['Guyane'],
#  [],
#  ['Brie'],
#  ['Limoges'],
#  ['Communauté', "d'", 'Agglomération'],
#  ['Métropole', 'Toulon', 'Provence', 'Méditerranée'],
#  [],
#  [],
#  [],
#  ['Boucles', 'de', 'Seine', 'et', 'Eure'],
#  ['FABrique', 'des', 'MOBilités'],
#  [],
#  ['du', 'Havre'],
#  ['Le', 'Havre', 'Seine', 'Métropole'],
#  ['Chapelle', "d'", 'Armentières'],
#  ['BRETEIL'],
#  [],
#  [],
#  [],
#  ['e'],
#  ['Communauté', "d'", 'agglomération'],
#  ['Ville', 'TALANT'],
#  ['Aix', 'Marseille', 'Provence'],
#  ['Iffendic'],
#  ['Soyaux'],
#  [],
#  ['Saint-Gonlay'],
#  ['La', 'Nouaye'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Roannais'],
#  ['Rodez'],
#  [],
#  ['Sainte-Adresse'],
#  ['Seine'],
#  ['Communauté', "d'", 'agglomération', 'du', 'Boulonnais'],
#  [],
#  ['Geowebservice'],
#  [],
#  ['Lorraine'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', "l'", 'Aube'],
#  ['Alsace'],
#  ['Corse-du-Sud'],
#  ['Haute-Vienne'],
#  ['EmTech', 'Europe'],
#  ['Communauté', 'de', 'Communes', 'Coeur', 'Côte', 'Fleurie'],
#  [],
#  ['Saint-Apollinaire'],
#  [],
#  [],
#  ['Lannion', 'Trégor', 'Communauté'],
#  [],
#  [],
#  ["Pont-l'Abbé"],
#  ['Redon'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', "l'", 'Orne'],
#  [],
#  ['Brest', 'métropole'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'de',
#   "l'",
#   'Hérault'],
#  [],
#  ['Département', 'des', 'Hautes-Alpes'],
#  ['Saint-Brieuc', 'Armor'],
#  [],
#  [],
#  [],
#  ['Aix-les-Bains'],
#  ['Direction', 'Départementale', 'des', 'Territoires', "d'", 'Indre-et-Loire'],
#  [],
#  ['CHATEAU-ARNOUX-SAINT-AUBAN'],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', 'de', 'Communes'],
#  ['Grand', 'Nancy'],
#  ['Aire-sur-Adour'],
#  ['Départemental', 'de', "l'", 'Ariège'],
#  ['Départemental', 'de', 'Vaucluse'],
#  ['Dreux'],
#  ['Auvergne', 'Rhône', 'Alpes'],
#  ['DatARA', 'Auvergne', 'Rhône', 'Alpes'],
#  [],
#  ['Saint-Louis', 'Agglomération'],
#  [],
#  ['Coeur', "d'", 'Essonne', 'Agglomération'],
#  ['Asnières-sur-Seine'],
#  [],
#  [],
#  [],
#  [],
#  ['Mogneneins'],
#  ['Noyal', 'Pontivy'],
#  [],
#  [],
#  ['Loire'],
#  ['Lanester'],
#  [],
#  ['Communauté', 'de', 'Communes', 'Vitry', 'Champagne'],
#  [],
#  ['ROQUEFORT', 'BEDOULE'],
#  [],
#  [],
#  ['GUYANE'],
#  ['Département', 'de', "l'", 'Aube'],
#  [],
#  ['St'],
#  ['Départemental'],
#  [],
#  [],
#  ['Meudon'],
#  ['Bretagne'],
#  ['Région', 'Bourgogne', 'Franche', 'Comté'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'du', 'Haut-Rhin'],
#  ['Tarn-et-Garonne'],
#  ['Rennes', 'Métropole'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'la', 'Lozère'],
#  ['Indre'],
#  ['Pas-de-Calais'],
#  ['Drôme'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'Atlantiques'],
#  ['DDTM', 'Gard'],
#  ['Lorraine'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'du',
#   'Var'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'la', 'Corrèze'],
#  ['Alpes', 'Maritimes'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', "l'", 'Essonne'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'Loir-et-Cher'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'de',
#   'Charente',
#   'Maritime'],
#  ['Languedoc', 'Roussillon'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'du',
#   'Val',
#   "d'",
#   'Oise'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'la', 'Marne'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'Saône-et-Loire'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'des',
#   'Landes'],
#  ['Poitou', 'Charentes'],
#  ['de', "l'", 'Isère'],
#  ['Lorient', 'Agglomération'],
#  ['Direction', 'Départementale', 'des', 'Territoire', 'du', 'Puy-de-Dôme'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'de',
#   'la',
#   'Haute-Loire'],
#  ['Occitanie'],
#  ['Agrocampus', 'Ouest'],
#  ['Communauté', 'de', 'communes', 'du', 'Val', "d'", 'Ille', 'Aubigné'],
#  [],
#  ['Tarn'],
#  ['Auvergne', 'Rhône', 'Alpes'],
#  ['de', "l'", 'Ain'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'du',
#   'Calvados'],
#  [],
#  [],
#  ['de', 'la', 'Meuse'],
#  ['Midi', 'Pyrénées'],
#  ['Nouvelle', 'Aquitaine'],
#  ['Martinique'],
#  ['Hautes-Alpes'],
#  ['Aveyron'],
#  ['Haute-Corse'],
#  ['Finistère'],
#  ['Haute-Garonne'],
#  ['Jura'],
#  ['Lot'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   'de',
#   'la',
#   'Somme'],
#  ['Mayenne'],
#  ['Morbihan'],
#  ['Seine', 'Maritime'],
#  ['Deux', 'Sèvres'],
#  ['Creuse'],
#  ['Yonne'],
#  ['Haute-Normandie'],
#  ['Martinique'],
#  ['Guyane'],
#  ['Bassin', 'Adour', 'garonne'],
#  [],
#  [],
#  ['Parc', 'naturel', 'régional', 'de', 'la', 'Montagne', 'de', 'Reims'],
#  ['Département', 'de', 'la', 'Charente', 'Maritime'],
#  [],
#  ['Élysée', 'République'],
#  [],
#  ['Départemental', "d'", 'Energies', 'de', "l'", 'Indre'],
#  ['Département', 'de', 'la', 'Vienne'],
#  ['FRANCE'],
#  ['Baraqueville'],
#  ['Auvergne'],
#  ['Communauté', "d'", 'Agglomeration', 'Versailles'],
#  ['Auvergne', 'Rhône', 'Alpes'],
#  [],
#  ['Pays', 'Midi', 'Quercy'],
#  ['SGAR', 'Occitanie'],
#  ['Occitanie'],
#  [],
#  [],
#  [],
#  ['Castelnaudary'],
#  [],
#  [],
#  ['Paris', 'Sud'],
#  [],
#  ['Centre', 'Régional', 'Rhône', 'Alpes'],
#  [],
#  ["Mouv'", 'Oise'],
#  [],
#  [],
#  ['Pradet'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Rectorat', 'de', 'Caen'],
#  ['Départemental', "d'", 'Energies', 'de', 'la', 'Drôme'],
#  [],
#  ["l'", 'Ardèche'],
#  [],
#  [],
#  ['Cugnaux'],
#  ['Loir-et-Cher'],
#  ['Indre-et-Loire'],
#  ['Sicoval', 'communauté', "d'", 'agglomération', 'du', 'Sud-Est'],
#  ['Beauvais'],
#  ['Département', 'de', "l'", 'Ain'],
#  [],
#  [],
#  [],
#  ['Vienne'],
#  ['Yvelines'],
#  ['Savoie'],
#  ['Dordogne'],
#  ['Nièvre'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'de', 'Lot-et-Garonne'],
#  ['Hérault'],
#  ['Centre', 'Val', 'de', 'Loire'],
#  [],
#  ['Île-de-France'],
#  ['Champagne', 'Ardenne'],
#  ['Franche', 'Comté'],
#  ['Bourgogne'],
#  ['Basse-Normandie'],
#  ['Plaintel'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Moselle'],
#  ['Direction',
#   'Départementale',
#   'des',
#   'Territoires',
#   'et',
#   'de',
#   'la',
#   'Mer',
#   "d'",
#   'Ille-et-Vilaine'],
#  ['Ville', 'de', 'Sèvres'],
#  ['Centre'],
#  [],
#  [],
#  ['La', 'Réunion'],
#  ['Direction', 'Départementale', 'des', 'Territoires', 'du', 'Loiret'],
#  ['Centre', 'Val', 'de', 'Loire'],
#  ['Direction', 'Départementale', 'Territoires', 'du', 'Cantal'],
#  ['RunningMap.org'],
#  [],
#  [],
#  ['Communuaté', 'de', 'Communes', 'du', 'Frontonnais'],
#  [],
#  [],
#  [],
#  [],
#  ['Communauté', "d'", 'Agglomération', 'de', 'Rambouillet', 'Territoires'],
#  ['Plantes', 'Invasives'],
#  ['Vanves'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Wikimédia', 'France'],
#  [],
#  ['Saint-Malo'],
#  [],
#  ['Faugères'],
#  ['MémorialGenWeb'],
#  [],
#  [],
#  [],
#  [],
#  ['Picardie'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Muséum', 'National', "d'", 'Histoire', 'Naturelle'],
#  [],
#  [],
#  ['Franche', 'Comté'],
#  ['Aquitaine'],
#  [],
#  [],
#  ['SOREGIES'],
#  ['Départemental', "d'", 'Energies', 'de', 'la', 'Dordogne'],
#  ...]

# %%
#np.save('../../data/locs_org_alg0.npy',np.array(all_locs), fix_imports=True, allow_pickle=True)

# %%
stop_loc=['Région', 'Métropole', 'Region', 'Metropole','Mer', 'mer', 'Département', 'DEPARTEMENT', 'Agglomération', 'agglomération','Communauté', 'communauté']

# %%
all_locs_ns=[None]*len(all_locs)
for i in range(len(all_locs)):
    mini_list=[x for x in all_locs[i] if x not in stop_loc]
    all_locs_ns[i]=mini_list

# %%
all_locs_ns_str=all_locs_ns
for i in range(len(all_locs_ns)):
    all_locs_ns_str[i]=' '.join(all_locs_ns[i])

# %%
len(all_locs_ns_str)
# Out:
# 1161

# %%
all_locs_np=np.array(all_locs)

# %%
np.save('../../data/locs_org_alg0.npy',np.array(all_locs_ns_str), fix_imports=True, allow_pickle=True)

# %%
#np.save('../../data/locs_insee_str.npy', all_locs_ns_str, allow_pickle=True)

# %% [markdown]
# ### Compare with insee tables

# %%
all_locs_ns_str=np.load('../../data/locs_insee_str.npy', allow_pickle=True)

# %%
all_locs_ns_str[:10]
# Out:
# array(['Paris île-de-france', 'Chambéry', 'chambéry Chambéry', 'corse',
#        'corse', 'orléans métropole Orléans', 'pr saint-denis geospatial',
#        '', '', 'capvern nan capvern département des hautes-pyrénées'],
#       dtype=object)

# %%
departements=pd.read_csv('../../data/departement2019.csv')
communes=pd.read_csv('../../data/communes-01012019.csv')
regions=pd.read_csv('../../data/region2019.csv')

# %%
communes_names=communes['nccenr'].to_numpy()

# %%
departements_names=departements['nccenr'].to_numpy()

# %%
regions_names=regions['nccenr'].to_numpy()

# %%
not_comm_names=list(departements_names)+list(regions_names)##+['France', 'Europe', 'Monde']

# %%
communes_prblm = list(np.load('../../data/communes_prblm.npy', allow_pickle=True))

# %%
np.save('../../data/communes_prblm.npy', np.array(communes_prblm, dtype=object), allow_pickle=True)

# %%
communes_prblm=[]
for i in communes_names:
    for j in not_comm_names:
        if fuzz.token_set_ratio(i,j)==100:
            communes_prblm.append(i)

# %%
all_locs_ns_str[25]
# Out:
# 'Saint-Claude'

# %%
regions_names
# Out:
# array(['Guadeloupe', 'Martinique', 'Guyane', 'La Réunion', 'Mayotte',
#        'Île-de-France', 'Centre-Val de Loire', 'Bourgogne-Franche-Comté',
#        'Normandie', 'Hauts-de-France', 'Grand Est', 'Pays de la Loire',
#        'Bretagne', 'Nouvelle-Aquitaine', 'Occitanie',
#        'Auvergne-Rhône-Alpes', "Provence-Alpes-Côte d'Azur", 'Corse'],
#       dtype=object)

# %%
from fuzzywuzzy import fuzz
def is_in(locs, category):
    values=[]
    for i in category:
        values.append(fuzz.token_set_ratio(locs, i))
        maxi=max(values)
    max_item=[i for i, j in enumerate(values) if j == maxi]   
   # print(max_item)
    if values[max_item[0]]==100:
        found=True
        if len(max_item)>1:
            values2=[]
            for w in max_item:
                values2.append(fuzz.ratio(locs, category[w]))
          #  print(values2)
            max_item_item=values2.index(max(values2))
            max_item=[max_item[max_item_item]]
    else:
        found=False
    return(max_item[0], found)

# %%
def text_to_loc(text):
    if text=='':
        return(None)
    if (text.find(' france')!=-1) or (text.find(' France')!=-1):
            return('France')
    max_item, found_c=is_in(text, communes_names)
    location=communes.loc[[max_item]]
    if communes_names[max_item] in communes_prblm:
        found_c=False
    if found_c==False:
        max_item, found_d=is_in(text, not_comm_names)
        try:
            location=departements.loc[[max_item]]
        except:
            location=regions.loc[[max_item-len(departements_names)]]
        return(location)
    return(location)

# %%
location=text_to_loc('Paris île-de-cité france.')

# %%
location
# Out:
# 'France'

# %%
'île de france'.find('  france')
# Out:
# -1

# %%
i=random.randint(1,len(all_locs_ns_str))
#i=27944
print('TEXTE INITIAL: '+ data_np[i])
t = time.time()
location=text_to_loc(all_locs_ns_str[i])
elapsed = time.time() - t
print('MOTS EXTRAITS'+ all_locs_ns_str[i])
print(' ')
print('Localisation INSEE:')
print(location)
print('Computed in '+str(elapsed) )
# Out:
# TEXTE INITIAL: tronçon de voie - saint-étienne-de-baïgorry. Saint-Étienne-de-Baïgorry . les voies sont représentées par leur axes et découpées chaque intersection. l’écriture des toponymes d’origine basque été validée par euskaltzaindia académie de la langue basque la mise jour est effectuée après délibération du conseil municipal.. adresse gps localisation voirie
# MOTS EXTRAITSde la Charente Maritime
#
# Localisation INSEE:
#    dep  reg cheflieu  tncc                ncc             nccenr  \
# 16  17   75    17300     3  CHARENTE MARITIME  Charente-Maritime
#
#               libelle
# 16  Charente-Maritime
# Computed in 6.5447328090667725

# %% [markdown]
# ### Essais avec une bonne precision donc plus de contrainte

# %%
from fuzzywuzzy import fuzz
def is_in(locs, category):
    values=[]
    for i in category:
        values.append(fuzz.partial_ratio(locs, i))
        maxi=max(values)
    max_item=[i for i, j in enumerate(values) if j == maxi]   
   # print(max_item)
    if values[max_item[0]]==100:
        found=True
        if len(max_item)>1:
            values2=[]
            for w in max_item:
                values2.append(fuzz.ratio(locs, category[w]))
          #  print(values2)
            max_item_item=values2.index(max(values2))
            max_item=[max_item[max_item_item]]
    else:
        found=False
    return(max_item[0], found)

# %%
def text_to_loc(text):
    if text=='':
        return(None)
    if (text.find(' france')!=-1) or (text.find(' France')!=-1):
            return('France')
    max_item, found_c=is_in(text, communes_names)
    location=communes.loc[[max_item]]
    if communes_names[max_item] in communes_prblm:
        found_c=False
    if found_c==False:
        max_item, found_d=is_in(text, not_comm_names)
        try:
            location=departements.loc[[max_item]]
        except:
            location=regions.loc[[max_item-len(departements_names)]]
        return(location)
    return(location)

# %%
i=random.randint(1,len(all_locs_ns_str))
#i=27944
print('TEXTE INITIAL: '+ data_single[i])
t = time.time()
location=text_to_loc(data_single[i])
elapsed = time.time() - t
print('MOTS EXTRAITS'+ data_single[i])
print(' ')
print('Localisation INSEE:')
print(location)
print('Computed in '+str(elapsed) )
# Out:
# TEXTE INITIAL: Parc Naturel Régional du Vercors
# MOTS EXTRAITSParc Naturel Régional du Vercors
#
# Localisation INSEE:
#       typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
# 14392     COM  35214  53.0  35  351     0  PARCE  Parcé   Parcé  3508
#
#        comparent
# 14392        NaN
# Computed in 6.616219997406006

# %%
from tqdm import tqdm
locations_orgs=[]
for i in tqdm(data_single):
    locations_orgs.append(text_to_loc(i))
# Out:
# 100%|██████████| 1161/1161 [2:07:57<00:00,  6.61s/it]

# %%
np.save('../../data/locs_org_alg1.npy',np.array(locations_orgs), fix_imports=True, allow_pickle=True)

# %%
locations_orgs
# Out:
# [      typecom    com   reg dep  arr  tncc    ncc nccenr libelle  can  \
#  31824     COM  75056  11.0  75  751     0  PARIS  Paris   Paris  NaN
#
#         comparent
#  31824        NaN  ,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr   libelle   can  \
#  31260     COM  73065  84.0  73  732     0  CHAMBERY  Chambéry  Chambéry  7399
#
#         comparent
#  31260        NaN  ,
#      reg cheflieu  tncc    ncc nccenr libelle
#  17   94    2A004     0  CORSE  Corse   Corse,
#        typecom    com   reg dep  arr  tncc      ncc   nccenr  libelle   can  \
#  17873     COM  45234  24.0  45  452     1  ORLEANS  Orléans  Orléans  4599
#
#         comparent
#  17873        NaN  ,
#      dep  reg cheflieu  tncc         ncc      nccenr     libelle
#  99  974    4    97411     0  LA REUNION  La Réunion  La Réunion,
#     reg cheflieu  tncc                  ncc               nccenr  \
#  6   24    45234     2  CENTRE VAL DE LOIRE  Centre-Val de Loire
#
#                 libelle
#  6  Centre-Val de Loire  ,
#        typecom    com   reg dep  arr  tncc        ncc     nccenr    libelle  \
#  27511     COM  64377  75.0  64  641     0  MENDIONDE  Mendionde  Mendionde
#
#          can  comparent
#  27511  6422        NaN  ,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr   libelle   can  \
#  27363     COM  64229  75.0  64  641     0  GAMARTHE  Gamarthe  Gamarthe  6412
#
#         comparent
#  27363        NaN  ,
#     reg cheflieu  tncc            ncc         nccenr        libelle
#  5   11    75056     1  ILE DE FRANCE  Île-de-France  Île-de-France,
#     reg cheflieu  tncc                  ncc               nccenr  \
#  6   24    45234     2  CENTRE VAL DE LOIRE  Centre-Val de Loire
#
#                 libelle
#  6  Centre-Val de Loire  ,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle  can  \
#  31824     COM  75056  11.0  75  751     0  PARIS  Paris   Paris  NaN
#
#         comparent
#  31824        NaN  ,
#     dep  reg cheflieu  tncc        ncc     nccenr    libelle
#  27  29   53    29232     2  FINISTERE  Finistère  Finistère,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr      libelle  \
#  36639     COM  88462  44.0  88  883     2  SYNDICAT  Syndicat  Le Syndicat
#
#          can  comparent
#  36639  8801        NaN  ,
#       typecom    com   reg dep  arr  tncc      ncc   nccenr  libelle   can  \
#  1985     COM  06004  93.0  06  061     1  ANTIBES  Antibes  Antibes  0694
#
#        comparent
#  1985        NaN  ,
#        typecom    com   reg dep  arr  tncc   ncc nccenr libelle   can  \
#  25717     COM  61476  28.0  61  613     0  SURE   Suré    Suré  6109
#
#         comparent
#  25717        NaN  ,
#     dep  reg cheflieu  tncc               ncc            nccenr  \
#  44  44   52    44109     3  LOIRE ATLANTIQUE  Loire-Atlantique
#
#               libelle
#  44  Loire-Atlantique  ,
#     reg cheflieu  tncc            ncc         nccenr        libelle
#  5   11    75056     1  ILE DE FRANCE  Île-de-France  Île-de-France,
#     reg cheflieu  tncc                  ncc               nccenr  \
#  6   24    45234     2  CENTRE VAL DE LOIRE  Centre-Val de Loire
#
#                 libelle
#  6  Centre-Val de Loire  ,
#     dep  reg cheflieu  tncc      ncc   nccenr  libelle
#  34  34   76    34172     5  HERAULT  Hérault  Hérault,
#     dep  reg cheflieu  tncc            ncc         nccenr        libelle
#  31  31   76    31555     3  HAUTE GARONNE  Haute-Garonne  Haute-Garonne,
#      reg cheflieu  tncc               ncc            nccenr           libelle
#  11   52    44109     4  PAYS DE LA LOIRE  Pays de la Loire  Pays de la Loire,
#        typecom    com   reg dep  arr  tncc         ncc      nccenr     libelle  \
#  28880     COM  67482  44.0  67  678     0  STRASBOURG  Strasbourg  Strasbourg
#
#          can  comparent
#  28880  6799        NaN  ,
#     dep  reg cheflieu  tncc    ncc nccenr libelle
#  23  25   27    25056     2  DOUBS  Doubs   Doubs,
#       typecom    com   reg dep  arr  tncc   ncc nccenr libelle   can  comparent
#  2069     COM  06088  93.0  06  062     0  NICE   Nice    Nice  0699        NaN,
#     dep  reg cheflieu  tncc  ncc nccenr libelle
#  83  83   93    83137     2  VAR    Var     Var,
#        typecom    com   reg dep  arr  tncc           ncc        nccenr  \
#  16080     COM  39478  27.0  39  393     0  SAINT CLAUDE  Saint-Claude
#
#              libelle   can  comparent
#  16080  Saint-Claude  3914        NaN  ,
#     dep  reg cheflieu  tncc    ncc nccenr libelle
#  55  55   44    55029     3  MEUSE  Meuse   Meuse,
#        typecom    com   reg dep  arr  tncc     ncc  nccenr libelle   can  \
#  17523     COM  44109  52.0  44  442     0  NANTES  Nantes  Nantes  4496
#
#         comparent
#  17523        NaN  ,
#        typecom    com   reg dep  arr  tncc         ncc      nccenr     libelle  \
#  14469     COM  35288  53.0  35  354     0  SAINT MALO  Saint-Malo  Saint-Malo
#
#          can  comparent
#  14469  3599        NaN  ,
#      reg cheflieu  tncc               ncc            nccenr           libelle
#  11   52    44109     4  PAYS DE LA LOIRE  Pays de la Loire  Pays de la Loire,
#        typecom    com   reg dep  arr  tncc  ncc nccenr libelle   can  comparent
#  12632     COM  31405  76.0  31  312     1  ORE    Ore     Ore  3102        NaN,
#      dep  reg cheflieu  tncc         ncc      nccenr     libelle
#  99  974    4    97411     0  LA REUNION  La Réunion  La Réunion,
#     reg cheflieu  tncc            ncc         nccenr        libelle
#  5   11    75056     1  ILE DE FRANCE  Île-de-France  Île-de-France,
#      reg cheflieu  tncc               ncc            nccenr           libelle
#  11   52    44109     4  PAYS DE LA LOIRE  Pays de la Loire  Pays de la Loire,
#    dep  reg cheflieu  tncc           ncc        nccenr       libelle
#  4  05   93    05061     4  HAUTES ALPES  Hautes-Alpes  Hautes-Alpes,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr      libelle  \
#  36639     COM  88462  44.0  88  883     2  SYNDICAT  Syndicat  Le Syndicat
#
#          can  comparent
#  36639  8801        NaN  ,
#     reg cheflieu  tncc            ncc         nccenr        libelle
#  5   11    75056     1  ILE DE FRANCE  Île-de-France  Île-de-France,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
#  15052     COM  37261  24.0  37  372     0  TOURS  Tours   Tours  3799
#
#         comparent
#  15052        NaN  ,
#     dep  reg cheflieu  tncc                ncc             nccenr  \
#  93  93   11    93008     3  SEINE SAINT DENIS  Seine-Saint-Denis
#
#                libelle
#  93  Seine-Saint-Denis  ,
#      reg cheflieu  tncc                         ncc  \
#  16   93    13055     0  PROVENCE ALPES COTE D AZUR
#
#                          nccenr                     libelle
#  16  Provence-Alpes-Côte d'Azur  Provence-Alpes-Côte d'Azur  ,
#     dep  reg cheflieu  tncc        ncc     nccenr    libelle
#  27  29   53    29232     2  FINISTERE  Finistère  Finistère,
#     dep  reg cheflieu  tncc                ncc             nccenr  \
#  93  93   11    93008     3  SEINE SAINT DENIS  Seine-Saint-Denis
#
#                libelle
#  93  Seine-Saint-Denis  ,
#        typecom    com   reg dep  arr  tncc    ncc nccenr    libelle   can  \
#  12069     COM  30197  76.0  30  301     4  PLANS  Plans  Les Plans  3003
#
#         comparent
#  12069        NaN  ,
#     dep  reg cheflieu  tncc     ncc  nccenr libelle
#  14  15   84    15014     2  CANTAL  Cantal  Cantal,
#     reg cheflieu  tncc            ncc         nccenr        libelle
#  5   11    75056     1  ILE DE FRANCE  Île-de-France  Île-de-France,
#     dep  reg cheflieu  tncc           ncc        nccenr       libelle
#  94  94   11    94028     2  VAL DE MARNE  Val-de-Marne  Val-de-Marne,
#     dep  reg cheflieu  tncc   ncc nccenr libelle
#  10  11   76    11069     5  AUDE   Aude    Aude,
#     reg cheflieu  tncc                      ncc                   nccenr  \
#  7   27    21231     0  BOURGOGNE FRANCHE COMTE  Bourgogne-Franche-Comté
#
#                     libelle
#  7  Bourgogne-Franche-Comté  ,
#      reg cheflieu  tncc                 ncc              nccenr  \
#  13   75    33063     3  NOUVELLE AQUITAINE  Nouvelle-Aquitaine
#
#                 libelle
#  13  Nouvelle-Aquitaine  ,
#    dep  reg cheflieu  tncc                      ncc                   nccenr  \
#  3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                     libelle
#  3  Alpes-de-Haute-Provence  ,
#     dep  reg cheflieu  tncc     ncc  nccenr libelle
#  14  15   84    15014     2  CANTAL  Cantal  Cantal,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr   libelle   can  \
#  12783     COM  31555  76.0  31  313     0  TOULOUSE  Toulouse  Toulouse  3199
#
#         comparent
#  12783        NaN  ,
#     dep  reg cheflieu  tncc                   ncc                nccenr  \
#  64  64   75    64445     4  PYRENEES ATLANTIQUES  Pyrénées-Atlantiques
#
#                   libelle
#  64  Pyrénées-Atlantiques  ,
#        typecom    com   reg dep  arr  tncc                ncc  \
#  32970     COM  77373  11.0  77  775     0  PONTAULT COMBAULT
#
#                    nccenr            libelle   can  comparent
#  32970  Pontault-Combault  Pontault-Combault  7717        NaN  ,
#     reg cheflieu  tncc              ncc           nccenr          libelle
#  9   32    59350     4  HAUTS DE FRANCE  Hauts-de-France  Hauts-de-France,
#      reg cheflieu  tncc               ncc            nccenr           libelle
#  11   52    44109     4  PAYS DE LA LOIRE  Pays de la Loire  Pays de la Loire,
#     dep  reg cheflieu  tncc          ncc       nccenr      libelle
#  52  52   44    52121     3  HAUTE MARNE  Haute-Marne  Haute-Marne,
#        typecom    com   reg dep  arr  tncc                  ncc  \
#  37511     COM  92040  11.0  92  923     1  ISSY LES MOULINEAUX
#
#                      nccenr              libelle   can  comparent
#  37511  Issy-les-Moulineaux  Issy-les-Moulineaux  9215        NaN  ,
#     dep  reg cheflieu  tncc             ncc          nccenr         libelle
#  47  47   75    47001     2  LOT ET GARONNE  Lot-et-Garonne  Lot-et-Garonne,
#    dep  reg cheflieu  tncc                      ncc                   nccenr  \
#  3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                     libelle
#  3  Alpes-de-Haute-Provence  ,
#    dep  reg cheflieu  tncc    ncc nccenr libelle
#  1  02   32    02408     5  AISNE  Aisne   Aisne,
#     dep  reg cheflieu  tncc       ncc    nccenr   libelle
#  13  14   28    14118     2  CALVADOS  Calvados  Calvados,
#      reg cheflieu  tncc       ncc    nccenr   libelle
#  12   53    35238     0  BRETAGNE  Bretagne  Bretagne,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr      libelle  \
#  36639     COM  88462  44.0  88  883     2  SYNDICAT  Syndicat  Le Syndicat
#
#          can  comparent
#  36639  8801        NaN  ,
#     dep  reg cheflieu  tncc             ncc          nccenr         libelle
#  37  37   24    37261     1  INDRE ET LOIRE  Indre-et-Loire  Indre-et-Loire,
#      reg cheflieu  tncc       ncc    nccenr   libelle
#  12   53    35238     0  BRETAGNE  Bretagne  Bretagne,
#      reg cheflieu  tncc        ncc     nccenr    libelle
#  14   76    31555     1  OCCITANIE  Occitanie  Occitanie,
#     reg cheflieu  tncc                      ncc                   nccenr  \
#  7   27    21231     0  BOURGOGNE FRANCHE COMTE  Bourgogne-Franche-Comté
#
#                     libelle
#  7  Bourgogne-Franche-Comté  ,
#     dep  reg cheflieu  tncc          ncc       nccenr      libelle
#  70  70   27    70550     3  HAUTE SAONE  Haute-Saône  Haute-Saône,
#     dep  reg cheflieu  tncc              ncc           nccenr          libelle
#  65  65   76    65440     4  HAUTES PYRENEES  Hautes-Pyrénées  Hautes-Pyrénées,
#        typecom    com   reg dep  arr  tncc     ncc  nccenr libelle   can  \
#  17523     COM  44109  52.0  44  442     0  NANTES  Nantes  Nantes  4496
#
#         comparent
#  17523        NaN  ,
#     dep  reg cheflieu  tncc      ncc   nccenr  libelle
#  11  12   76    12202     5  AVEYRON  Aveyron  Aveyron,
#      reg cheflieu  tncc    ncc nccenr libelle
#  17   94    2A004     0  CORSE  Corse   Corse,
#       typecom    com   reg dep  arr  tncc     ncc  nccenr    libelle   can  \
#  9785     COM  26068  84.0  26  263     2  CHALON  Chalon  Le Chalon  2605
#
#        comparent
#  9785        NaN  ,
#       typecom    com   reg dep  arr  tncc         ncc      nccenr     libelle  \
#  5260     COM  14635  28.0  14  142     0  SAINT OMER  Saint-Omer  Saint-Omer
#
#         can  comparent
#  5260  1422        NaN  ,
#      reg cheflieu  tncc        ncc     nccenr    libelle
#  10   44    67482     2  GRAND EST  Grand Est  Grand Est,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
#  25203     COM  60676  32.0  60  603     0  VILLE  Ville   Ville  6017
#
#         comparent
#  25203        NaN  ,
#      reg cheflieu  tncc                         ncc  \
#  16   93    13055     0  PROVENCE ALPES COTE D AZUR
#
#                          nccenr                     libelle
#  16  Provence-Alpes-Côte d'Azur  Provence-Alpes-Côte d'Azur  ,
#     dep  reg cheflieu  tncc        ncc     nccenr    libelle
#  27  29   53    29232     2  FINISTERE  Finistère  Finistère,
#        typecom    com   reg dep  arr  tncc                 ncc  \
#  37691     COM  95268  11.0  95  952     0  GARGES LES GONESSE
#
#                     nccenr             libelle   can  comparent
#  37691  Garges-lès-Gonesse  Garges-lès-Gonesse  9511        NaN  ,
#     dep  reg cheflieu  tncc            ncc         nccenr        libelle
#  20  22   53    22278     4  COTES D ARMOR  Côtes-d'Armor  Côtes-d'Armor,
#        typecom    com   reg dep  arr  tncc      ncc   nccenr  libelle   can  \
#  24371     COM  59512  32.0  59  595     0  ROUBAIX  Roubaix  Roubaix  5998
#
#         comparent
#  24371        NaN  ,
#  'France',
#     dep  reg cheflieu  tncc     ncc  nccenr libelle
#  73  73   84    73065     3  SAVOIE  Savoie  Savoie,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr      libelle  \
#  36639     COM  88462  44.0  88  883     2  SYNDICAT  Syndicat  Le Syndicat
#
#          can  comparent
#  36639  8801        NaN  ,
#      reg cheflieu  tncc       ncc    nccenr   libelle
#  12   53    35238     0  BRETAGNE  Bretagne  Bretagne,
#      reg cheflieu  tncc               ncc            nccenr           libelle
#  11   52    44109     4  PAYS DE LA LOIRE  Pays de la Loire  Pays de la Loire,
#        typecom    com   reg dep  arr  tncc   ncc nccenr libelle   can  \
#  16504     COM  40323  75.0  40  402     0  VERT   Vert    Vert  4008
#
#         comparent
#  16504        NaN  ,
#        typecom    com   reg dep  arr  tncc         ncc      nccenr     libelle  \
#  22002     COM  55029  44.0  55  551     0  BAR LE DUC  Bar-le-Duc  Bar-le-Duc
#
#          can  comparent
#  22002  5598        NaN  ,
#     dep  reg cheflieu  tncc      ncc   nccenr  libelle
#  33  33   75    33063     3  GIRONDE  Gironde  Gironde,
#        typecom    com   reg dep  arr  tncc         ncc      nccenr     libelle  \
#  22002     COM  55029  44.0  55  551     0  BAR LE DUC  Bar-le-Duc  Bar-le-Duc
#
#          can  comparent
#  22002  5598        NaN  ,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
#  14392     COM  35214  53.0  35  351     0  PARCE  Parcé   Parcé  3508
#
#         comparent
#  14392        NaN  ,
#      reg cheflieu  tncc       ncc    nccenr   libelle
#  12   53    35238     0  BRETAGNE  Bretagne  Bretagne,
#    dep  reg cheflieu  tncc                      ncc                   nccenr  \
#  3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                     libelle
#  3  Alpes-de-Haute-Provence  ,
#      reg cheflieu  tncc                         ncc  \
#  16   93    13055     0  PROVENCE ALPES COTE D AZUR
#
#                          nccenr                     libelle
#  16  Provence-Alpes-Côte d'Azur  Provence-Alpes-Côte d'Azur  ,
#    dep  reg cheflieu  tncc  ncc nccenr libelle
#  0  01   84    01053     5  AIN    Ain     Ain,
#        typecom    com   reg dep  arr  tncc   ncc nccenr libelle   can  \
#  18342     COM  47001  75.0  47  471     1  AGEN   Agen    Agen  4797
#
#         comparent
#  18342        NaN  ,
#     dep  reg cheflieu  tncc   ncc nccenr libelle
#  61  61   28    61001     5  ORNE   Orne    Orne,
#        typecom    com   reg dep  arr  tncc           ncc        nccenr  \
#  14244     COM  35069  53.0  35  353     0  CHATEAUGIRON  Châteaugiron
#
#              libelle   can  comparent
#  14244  Châteaugiron  3505        NaN  ,
#    dep  reg cheflieu  tncc       ncc    nccenr   libelle
#  7  08   44    08105     4  ARDENNES  Ardennes  Ardennes,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr      libelle  \
#  36639     COM  88462  44.0  88  883     2  SYNDICAT  Syndicat  Le Syndicat
#
#          can  comparent
#  36639  8801        NaN  ,
#  'France',
#     dep  reg cheflieu  tncc           ncc        nccenr       libelle
#  26  28   24    28085     1  EURE ET LOIR  Eure-et-Loir  Eure-et-Loir,
#       typecom    com   reg dep  arr  tncc        ncc     nccenr    libelle  \
#  4559     COM  13055  93.0  13  133     0  MARSEILLE  Marseille  Marseille
#
#         can  comparent
#  4559  1398        NaN  ,
#     dep  reg cheflieu  tncc       ncc    nccenr   libelle
#  67  67   44    67482     2  BAS RHIN  Bas-Rhin  Bas-Rhin,
#     dep  reg cheflieu  tncc                  ncc               nccenr  \
#  66  66   76    66136     4  PYRENEES ORIENTALES  Pyrénées-Orientales
#
#                  libelle
#  66  Pyrénées-Orientales  ,
#        typecom    com   reg dep  arr  tncc              ncc           nccenr  \
#  37545     COM  93039  11.0  93  933     5  ILE SAINT DENIS  Île-Saint-Denis
#
#                   libelle   can  comparent
#  37545  L'Île-Saint-Denis  9318        NaN  ,
#     dep  reg cheflieu  tncc           ncc        nccenr       libelle
#  26  28   24    28085     1  EURE ET LOIR  Eure-et-Loir  Eure-et-Loir,
#        typecom    com  reg  dep  arr  tncc  ncc nccenr libelle  can  comparent
#  35550    COMD  85165  NaN  NaN  NaN     5  OIE    Oie   L'Oie  NaN    85084.0,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
#  24215     COM  59350  32.0  59  595     0  LILLE  Lille   Lille  5997
#
#         comparent
#  24215        NaN  ,
#    dep  reg cheflieu  tncc       ncc    nccenr   libelle
#  7  08   44    08105     4  ARDENNES  Ardennes  Ardennes,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr   libelle   can  \
#  15251     COM  38185  84.0  38  381     0  GRENOBLE  Grenoble  Grenoble  3898
#
#         comparent
#  15251        NaN  ,
#      reg cheflieu  tncc                   ncc                nccenr  \
#  15   84    69123     1  AUVERGNE RHONE ALPES  Auvergne-Rhône-Alpes
#
#                   libelle
#  15  Auvergne-Rhône-Alpes  ,
#    dep  reg cheflieu  tncc                      ncc                   nccenr  \
#  3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                     libelle
#  3  Alpes-de-Haute-Provence  ,
#    dep  reg cheflieu  tncc                      ncc                   nccenr  \
#  3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                     libelle
#  3  Alpes-de-Haute-Provence  ,
#        typecom    com   reg dep  arr  tncc   ncc nccenr libelle   can  \
#  25717     COM  61476  28.0  61  613     0  SURE   Suré    Suré  6109
#
#         comparent
#  25717        NaN  ,
#     dep  reg cheflieu  tncc                ncc             nccenr  \
#  93  93   11    93008     3  SEINE SAINT DENIS  Seine-Saint-Denis
#
#                libelle
#  93  Seine-Saint-Denis  ,
#        typecom    com   reg dep  arr  tncc       ncc    nccenr   libelle   can  \
#  35882     COM  86194  75.0  86  863     0  POITIERS  Poitiers  Poitiers  8699
#
#         comparent
#  35882        NaN  ,
#     dep  reg cheflieu  tncc              ncc           nccenr          libelle
#  82  82   76    82121     2  TARN ET GARONNE  Tarn-et-Garonne  Tarn-et-Garonne,
#      reg cheflieu  tncc                         ncc  \
#  16   93    13055     0  PROVENCE ALPES COTE D AZUR
#
#                          nccenr                     libelle
#  16  Provence-Alpes-Côte d'Azur  Provence-Alpes-Côte d'Azur  ,
#     reg cheflieu  tncc        ncc     nccenr    libelle
#  8   28    76540     0  NORMANDIE  Normandie  Normandie,
#     dep  reg cheflieu  tncc             ncc          nccenr         libelle
#  49  49   52    49007     2  MAINE ET LOIRE  Maine-et-Loire  Maine-et-Loire,
#        typecom    com   reg dep  arr  tncc    ncc nccenr libelle   can  \
#  14415     COM  35236  53.0  35  352     0  REDON  Redon   Redon  3517
#
#         comparent
#  14415        NaN  ,
#        typecom    com   reg dep  arr  tncc     ncc  nccenr libelle   can  \
#  18877     COM  49007  52.0  49  491     1  ANGERS  Angers  Angers  4998
#
#         comparent
#  18877        NaN  ,
#        typecom    com   reg dep  arr  tncc                    ncc  \
#  12602     COM  31375  76.0  31  311     0  MONTESQUIEU VOLVESTRE
#
#                        nccenr                libelle   can  comparent
#  12602  Montesquieu-Volvestre  Montesquieu-Volvestre  3101        NaN  ]

# %%
#39298 huat de france et français

# %%
all_locs_ns_str[20751]
# Out:
# 'rivière marne de châlons-en-champagne Direction Départementale des Territoires de la Marne'

# %%
communes_names[31343]#8183
# Out:
# 'Porte-de-Savoie'

# %%
other=list(regions_names)+list(departements_names)+['France']

# %%
communes
# Out:
#       typecom    com   reg  dep  arr  tncc                    ncc  \
# 0         COM  01001  84.0   01  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01  011     1                AMBLEON
# ...       ...    ...   ...  ...  ...   ...                    ...
# 37925     COM  97613   6.0  976  NaN     0          M TSANGAMOUJI
# 37926     COM  97614   6.0  976  NaN     1               OUANGANI
# 37927     COM  97615   6.0  976  NaN     0               PAMANDZI
# 37928     COM  97616   6.0  976  NaN     0                   SADA
# 37929     COM  97617   6.0  976  NaN     0               TSINGONI
#
#                       nccenr                  libelle    can  comparent
# 0      Abergement-Clémenciat  L'Abergement-Clémenciat   0108        NaN
# 1        Abergement-de-Varey    L'Abergement-de-Varey   0101        NaN
# 2          Ambérieu-en-Bugey        Ambérieu-en-Bugey   0101        NaN
# 3        Ambérieux-en-Dombes      Ambérieux-en-Dombes   0122        NaN
# 4                    Ambléon                  Ambléon   0104        NaN
# ...                      ...                      ...    ...        ...
# 37925          M'Tsangamouji            M'Tsangamouji  97613        NaN
# 37926               Ouangani                 Ouangani  97610        NaN
# 37927               Pamandzi                 Pamandzi  97611        NaN
# 37928                   Sada                     Sada  97612        NaN
# 37929               Tsingoni                 Tsingoni  97613        NaN
#
# [37930 rows x 11 columns]

# %%
dpt_prblm=[]
for i in departements_names:
    for j in regions_names:
        if fuzz.token_set_ratio(i,j)==100:
            dpt_prblm.append(i)

# %%
for i in communes_names:
    if fuzz.token_set_ratio(i,'drôme')==100:
        print(i)
# Out:
# Balleroy-sur-Drôme
# Lande-sur-Drôme
# Val de Drôme
# Livron-sur-Drôme
# Loriol-sur-Drôme

# %%
regions_names
# Out:
# array(['Guadeloupe', 'Martinique', 'Guyane', 'La Réunion', 'Mayotte',
#        'Île-de-France', 'Centre-Val de Loire', 'Bourgogne-Franche-Comté',
#        'Normandie', 'Hauts-de-France', 'Grand Est', 'Pays de la Loire',
#        'Bretagne', 'Nouvelle-Aquitaine', 'Occitanie',
#        'Auvergne-Rhône-Alpes', "Provence-Alpes-Côte d'Azur", 'Corse'],
#       dtype=object)

# %%
departements_names
# Out:
# array(['Ain', 'Aisne', 'Allier', 'Alpes-de-Haute-Provence',
#        'Hautes-Alpes', 'Alpes-Maritimes', 'Ardèche', 'Ardennes', 'Ariège',
#        'Aube', 'Aude', 'Aveyron', 'Bouches-du-Rhône', 'Calvados',
#        'Cantal', 'Charente', 'Charente-Maritime', 'Cher', 'Corrèze',
#        "Côte-d'Or", "Côtes-d'Armor", 'Creuse', 'Dordogne', 'Doubs',
#        'Drôme', 'Eure', 'Eure-et-Loir', 'Finistère', 'Corse-du-Sud',
#        'Haute-Corse', 'Gard', 'Haute-Garonne', 'Gers', 'Gironde',
#        'Hérault', 'Ille-et-Vilaine', 'Indre', 'Indre-et-Loire', 'Isère',
#        'Jura', 'Landes', 'Loir-et-Cher', 'Loire', 'Haute-Loire',
#        'Loire-Atlantique', 'Loiret', 'Lot', 'Lot-et-Garonne', 'Lozère',
#        'Maine-et-Loire', 'Manche', 'Marne', 'Haute-Marne', 'Mayenne',
#        'Meurthe-et-Moselle', 'Meuse', 'Morbihan', 'Moselle', 'Nièvre',
#        'Nord', 'Oise', 'Orne', 'Pas-de-Calais', 'Puy-de-Dôme',
#        'Pyrénées-Atlantiques', 'Hautes-Pyrénées', 'Pyrénées-Orientales',
#        'Bas-Rhin', 'Haut-Rhin', 'Rhône', 'Haute-Saône', 'Saône-et-Loire',
#        'Sarthe', 'Savoie', 'Haute-Savoie', 'Paris', 'Seine-Maritime',
#        'Seine-et-Marne', 'Yvelines', 'Deux-Sèvres', 'Somme', 'Tarn',
#        'Tarn-et-Garonne', 'Var', 'Vaucluse', 'Vendée', 'Vienne',
#        'Haute-Vienne', 'Vosges', 'Yonne', 'Territoire de Belfort',
#        'Essonne', 'Hauts-de-Seine', 'Seine-Saint-Denis', 'Val-de-Marne',
#        "Val-d'Oise", 'Guadeloupe', 'Martinique', 'Guyane', 'La Réunion',
#        'Mayotte'], dtype=object)

# %%
len(communes_prblm)
# Out:
# 809

# %%
data_np[3422]
# Out:
# "concentrations en nitrates d'origine agricole - - eaux souterraines - france entière. Système d'Information sur l'Eau. la directive 91 cee du 12 décembre dite directive nitrates vise protéger la qualité de eau en prévenant la pollution des eaux souterraines et superficielles par les nitrates d’origine agricole notamment en promouvant usage des bonnes pratiques agricoles de gestion de l’azote. ses orientations sont largement reprises dans la directive cadre sur l’eau dce 60 ce du 23 octobre . elle impose aux états membres de : •\tréaliser des campagnes de surveillance des concentrations en nitrates dans les milieux aquatiques eaux superficielles et souterraines au moins tous les quatre ans •\tdésigner des zones de protection spécifiques atteintes ou menacées par la pollution par les nitrates d’origine agricole dites zones vulnérables •\télaborer des programmes d’actions dont les mesures doivent être obligatoirement appliquées par les agriculteurs qui exercent leurs activités en zones vulnérables •\tétablir des bonnes pratiques agricoles fertilisation azotée gestion des terres mettre en œuvre volontairement par les agriculteurs. en france la mise en œuvre de la directive nitrates débute en avec la première campagne de surveillance : les concentrations en nitrates sont alors mesurées sur environ sites dits stations de mesure localisés dans ou près des zones agricoles. les résultats permettent d’établir la première délimitation des zones vulnérables en . puis quatre autres campagnes se succèdent et . en complément de ces campagnes spécifiques menées au titre de la directive nitrates et afin de mieux suivre l’évolution de la qualité de l’eau vis-à-vis de ce paramètre le ministère en charge de l’environnement office national de eau et des milieux aquatiques onema et l’office international de l’eau oieau réalisent chaque année depuis un document de synthèse sur les résultats des mesures de concentrations en nitrates produites dans le cadre du programme national de la surveillance des milieux aquatiques contrôle de surveillance contrôle opérationnel réseaux complémentaires en application de la dce. les stations de mesure sélectionnées pour étudier l’évolution des concentrations dans les zones soumises des pressions agricoles sont alors celles qui sont communes avec la dernière campagne menée au titre de la directive nitrates . ce jeu de données correspond aux résultats du programme national de surveillance réalisé au titre de la dce des stations sélectionnées lors de la campagne de surveillance nitrates sur la période allant du 01 10 au 30 09 pour les eaux souterraines. organisations partenaires office international de eau agences de eau offices de eau ars deal dreal consulter cette fiche sur datasets . donnees-ouvertes donnees-qualitatives eau-souterraine eaux-souterraines environment etat-du-milieu-qualite-quantite france-entiere passerelle-inspire pollution-de-leau qualite-de-lenvironnement"

# %% [markdown]
# ### Pandas concatenation and stuff

# %%
regions.loc[[10]]
# Out:
#     reg cheflieu  tncc        ncc     nccenr    libelle
# 10   44    67482     2  GRAND EST  Grand Est  Grand Est

# %%
departements.loc[[3]]
# Out:
#   dep  reg cheflieu  tncc                      ncc                   nccenr  \
# 3  04   93    04070     4  ALPES DE HAUTE PROVENCE  Alpes-de-Haute-Provence
#
#                    libelle
# 3  Alpes-de-Haute-Provence

# %%
communes.loc[[7563]]
# Out:
#      typecom    com   reg dep  arr  tncc        ncc     nccenr    libelle  \
# 7563     COM  21407  27.0  21  211     0  MESSANGES  Messanges  Messanges
#
#        can  comparent
# 7563  2118        NaN

# %%
result=pd.concat([regions.loc[[10]],departements.loc[[3]], communes.loc[[7563]]],  ignore_index=True, sort=False)

# %%
communes.loc[[7563]].append(departements.loc[3], ignore_index=True, sort=False)
# Out:
#   typecom    com   reg dep  arr  tncc                      ncc  \
# 0     COM  21407  27.0  21  211     0                MESSANGES
# 1     NaN    NaN  93.0  04  NaN     4  ALPES DE HAUTE PROVENCE
#
#                     nccenr                  libelle   can  comparent cheflieu
# 0                Messanges                Messanges  2118        NaN      NaN
# 1  Alpes-de-Haute-Provence  Alpes-de-Haute-Provence   NaN        NaN    04070

# %%
df=pd.DataFrame({'ncc':['France']})

# %%
df
# Out:
#       ncc
# 0  France

# %%
df.append(communes.loc[[7563]])
# Out:
#             ncc typecom    com   reg  dep  arr  tncc     nccenr    libelle  \
# 0        France     NaN    NaN   NaN  NaN  NaN   NaN        NaN        NaN
# 7563  MESSANGES     COM  21407  27.0   21  211   0.0  Messanges  Messanges
#
#        can  comparent
# 0      NaN        NaN
# 7563  2118        NaN

# %% [markdown]
# ### Essais avec subwords

# %%
resultats=[]
for loc in all_locs_ns_str:
    for ref in list(communes_names)+list(departements_names)+list(regions_names):
        if ref in loc.split():
            resultats.append((loc,ref))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-83f9f618c642> in <module>
#       2 for loc in all_locs_ns_str:
#       3     for ref in list(communes_names)+list(departements_names)+list(regions_names):
# ----> 4         if ref in loc.split():
#       5             resultats.append((loc,ref))
#
# KeyboardInterrupt:

# %%
resultats[:100]
# Out:
# [('Paris île-de-france', 'Paris'),
#  ('Paris île-de-france', 'Paris'),
#  ('Chambéry', 'Chambéry'),
#  ('chambéry Chambéry', 'Chambéry'),
#  ('orléans métropole Orléans', 'Orléans'),
#  ('gamarthe Gamarthe', 'Gamarthe'),
#  ('Île-de-France', 'Île-de-France'),
#  ('Paris Seine Ouest boulogne billancourt cadre-de-vie composteurs-en-pavillon issy-les-moulineaux larbre marnes-la-coquette mdna meudon plan vanves ville-davray',
#   'Paris'),
#  ('Paris Seine Ouest boulogne billancourt cadre-de-vie composteurs-en-pavillon issy-les-moulineaux larbre marnes-la-coquette mdna meudon plan vanves ville-davray',
#   'Paris'),
#  ('antibes Antibes', 'Antibes'),
#  ('loire atlantique epci de Loire Atlantique', 'Loire'),
#  ('île-de-france Île-de-France', 'Île-de-France'),
#  ('île-de-france Île-de-France', 'Île-de-France'),
#  ('val de loire Centre Val de Loire', 'Val'),
#  ('val de loire Centre Val de Loire', 'Val'),
#  ('val de loire Centre Val de Loire', 'Loire'),
#  ("hérault de l' Hérault hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("de l' Hérault", 'Hérault'),
#  ("de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("de l' Hérault france bayssan biterrois parc départemental de bessilles bessilles savignac territoire domaine-de-restinclieres",
#   'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("maisons de l' Hérault", 'Hérault'),
#  ("maisons de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault", 'Hérault'),
#  ("hérault de l' Hérault attractivite-et-innovation pdipr randonnee tourisme",
#   'Hérault'),
#  ('roques Haute-Garonne', 'Haute-Garonne'),
#  ('Eurométropole de Strasbourg qpv strasbourg data.strasbourg.eu adresse iris',
#   'Strasbourg'),
#  ('du Doubs', 'Doubs'),
#  ('du Doubs', 'Doubs'),
#  ('du Doubs', 'Doubs'),
#  ('du Doubs', 'Doubs'),
#  ('levens Nice', 'Nice'),
#  ("villefranche-sur-mer Nice Côte d' Azur", 'Nice'),
#  ("villefranche-sur-mer Nice Côte d' Azur", 'Azur'),
#  ("villefranche-sur-mer Nice Côte d' Azur", 'Côte'),
#  ('villefranche-sur-mer Nice', 'Nice'),
#  ("levens Nice Côte d' Azur levens levens", 'Nice'),
#  ("levens Nice Côte d' Azur levens levens", 'Azur'),
#  ("levens Nice Côte d' Azur levens levens", 'Côte'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('Saint-Claude', 'Saint-Claude'),
#  ('antibes Antibes', 'Antibes'),
#  ('jardins antibes Antibes', 'Antibes'),
#  ('nantes métropole planimétriques Nantes', 'Nantes'),
#  ('nantes métropole Nantes', 'Nantes'),
#  ('cms du Doubs', 'Doubs'),
#  ('cms du Doubs', 'Doubs'),
#  ('du Doubs', 'Doubs'),
#  ('du Doubs', 'Doubs'),
#  ('orléans métropole Orléans', 'Orléans'),
#  ('Orléans', 'Orléans'),
#  ('paris Paris paris paris paris gaule paris paris archeologie', 'Paris'),
#  ('paris Paris paris paris paris gaule paris paris archeologie', 'Paris'),
#  ('Paris', 'Paris'),
#  ('Paris', 'Paris'),
#  ('Paris', 'Paris'),
#  ('Paris', 'Paris'),
#  ('musées Île-de-France', 'Île-de-France'),
#  ('île-de-france Île-de-France', 'Île-de-France'),
#  ('orléans métropole Orléans', 'Orléans'),
#  ('Nice', 'Nice'),
#  ('vence Nice', 'Nice'),
#  ("Nice Côte d' Azur", 'Nice'),
#  ("Nice Côte d' Azur", 'Azur'),
#  ("Nice Côte d' Azur", 'Côte'),
#  ("vence Nice Côte d' Azur vence", 'Nice'),
#  ("vence Nice Côte d' Azur vence", 'Azur'),
#  ("vence Nice Côte d' Azur vence", 'Côte'),
#  ('antibes Antibes', 'Antibes'),
#  ('Paris suède europe france paris at tok = gacsxrm gryyd paris paris bois de boulogne du bois de vincennes grand paris actualite detail id',
#   'Paris'),
#  ('Paris suède europe france paris at tok = gacsxrm gryyd paris paris bois de boulogne du bois de vincennes grand paris actualite detail id',
#   'Paris'),
#  ('tours métropole val de loire Tours Val de Loire', 'Val'),
#  ('tours métropole val de loire Tours Val de Loire', 'Tours'),
#  ('tours métropole val de loire Tours Val de Loire', 'Val'),
#  ('tours métropole val de loire Tours Val de Loire', 'Loire'),
#  ('ville de saint-égrève Ville de Saint-Egrève', 'Ville'),
#  ('ville de saint-égrève Ville de Saint-Egrève', 'Ville'),
#  ('Ville de Saint-Egrève', 'Ville')]
