# %%
##### Takes a search query as input and get the vectors from the whole dataset to compare.
import spacy
import pickle
import numpy as np
from scipy import spatial
import sys
import unidecode
import pandas as pd
#from sklearn.decomposition import PCA
#QUERY  Neighbours Ids_and_Score_bool
directory='../'
argv=sys.argv
nlp = spacy.load("fr_core_news_lg")
pca = pickle.load(open(directory+'models/pca_30.pkl','rb'))
pca_space= np.load(directory+'models/vectors_pca_30.npy', allow_pickle=True)
id_table=list(np.load(directory+'../data/id_table.npy', allow_pickle=True))
tree = spatial.KDTree(pca_space)
from spacy.lang.fr.stop_words import STOP_WORDS
from spacy.lang.fr import French
parser=French()
stopwords = list(STOP_WORDS)

def process_query(search_query):
    query=str(search_query).lower()
    clean_query = unidecode.unidecode(query)
    tokens=parser(clean_query)
    tokens = [ word.lower_ for word in tokens ]
    tokens = [ word for word in tokens if word not in stopwords]
    tokens = " ".join([i for i in tokens])
    return (tokens)

def query2vec(search_query):
    x=nlp(search_query).vector #spacy 300d
    y=pca.transform([x])[0] #pca 30d
    return(y)

def get_id(idx):
    dataset_id=id_table[idx]
    return(dataset_id)

def get_idx(ids):
    dataset_idx=id_table.index(ids)
    return(dataset_idx)

def id2vec(ids):
    return(pca_space[get_idx(ids)])

def neighbours(vector, n):
    n_ids=[]
    score=[]
    dist, pos=tree.query(vector, k=n)
    for j in range(len(pos)):
        n_ids.append(get_id(pos[j]))
        score.append(1-dist[j]/50) ##very approximate metric 
    return(n_ids, score)

def Search(search_query, n):
    n_ids, score=neighbours(query2vec(process_query(search_query)), n)
    #print(n_ids, score)
    return(n_ids, score)

def Similarity(ids, n):
    n_ids, score=neighbours(id2vec(ids), n)
    return(n_ids, score)
# Out:
# /home/florian/.local/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator PCA from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
with open('../../data/google_results_ids.json') as json_data:
    data = json.load(json_data)

google_df=pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))

# %%
def load_queries(path='../../data/querys.csv'):
    df=pd.read_csv('../../data/querys.csv', sep=',',error_bad_lines=False, encoding='latin-1')
    ids=df['expected']
    queries=np.array(df['query'], dtype=str)
    return queries, ids

# %%
queries, ids = load_queries()

# %%
queries
# Out:
# array(['siren', 'sirene', 'entreprise', 'entreprises', 'siret',
#        'open damir', 'opendamir', 'damir', 'contours départements',
#        'emissions polluantes', 'géofla départements',
#        'effectifs police municipale', 'marchés public bourgogne',
#        'Liste gares SNCF', 'contours départements français',
#        'loi de finance 2016', 'lolf 2016', 'formations pas de calais',
#        'accidents de la circulation', 'accidents de la route',
#        'risque de décès un an après accident', 'COG',
#        'code officiel géographique', 'contour commune',
#        'contours communes', 'contour communes', 'code postal',
#        'codes postaux', 'prénoms', 'association', 'associations', 'RNA',
#        'nan', 'répertoire des associations',
#        'répertoire national des associations', 'waldec',
#        'organismes de formation', 'organisme de formation',
#        'bibliothèques', "annuaire de l'éducation", 'grand débat',
#        'vie-publique répertoire'], dtype='<U36')

# %%
queries.remove('vie-publique répertoire')

# %%
for i in range(len(queries)):
    print(google_df[queries[i]])
# Out:
# 0     5b7ffc618b4c4169d30727e0
# 1     5e719db34444483bd0a1a2b9
# 2     58ef2cfda3a7293d49c4e17a
# 3     58d27679a3a7297c157fe3ae
# 4     5c37848906e3e77914d00e71
# 5     5971fbe588ee38522976e8f0
# 6     5dd651758b4c410aeb6582e6
# 7     5369956ba3a729239d2046fc
# 8     5a097ae9c751df643bf1b500
# 9     57092f51a3a72944fcc6ab40
# 10    54f63501c751df466f882844
# 11    5530fbacc751df5ff937dddb
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: siren, dtype: object
# 0     5b7ffc618b4c4169d30727e0
# 1     5e719db34444483bd0a1a2b9
# 2     58ef2cfda3a7293d49c4e17a
# 3     58d27679a3a7297c157fe3ae
# 4     5971fbe588ee38522976e8f0
# 5     5dd651758b4c410aeb6582e6
# 6     5c37848906e3e77914d00e71
# 7     5eed7bbeb63de854684fc1c2
# 8     5a22644f88ee3848529af925
# 9     54f63501c751df466f882844
# 10    593457c6a3a72968e2876bf3
# 11    5530fbacc751df5ff937dddb
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: sirene, dtype: object
# 0     5e9dbdbe71589194c8f7b42f
# 1     53699569a3a729239d2046eb
# 2     5c6adbae634f4114a5c41776
# 3     536995aba3a729239d2047ad
# 4     53698f16a3a729239d203648
# 5     53ca2be2a3a7294a1ddd7847
# 6     5ecf5df0eb87ae4934709e30
# 7     5ebc1ab7e5d3010d32ca8260
# 8     5668697e88ee381d74af0bf4
# 9     5cd57bf68b4c4179299eb0e9
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: entreprises, dtype: object
# 0     5b7ffc618b4c4169d30727e0
# 1     5e719db34444483bd0a1a2b9
# 2     5a970f31c751df6d181a6c2a
# 3     58ef2cfda3a7293d49c4e17a
# 4     5e7201d522f2a43e9f736a9a
# 5     58d27679a3a7297c157fe3ae
# 6     5971fbe588ee38522976e8f0
# 7     59591a8ca3a7291dcf9c810f
# 8     5c37848906e3e77914d00e71
# 9     53699569a3a729239d2046eb
# 10    58e70f7ba3a7294acc083ef9
# 11    5dd651758b4c410aeb6582e6
# 12    5369956ba3a729239d2046fc
# 13    58b69b58a3a7295a7c825129
# 14    559395f1c751df0f51a453b9
# 15    5537bf2bc751df66296dd01b
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: siret, dtype: object
# 0     54de1e8fc751df388646738b
# 1     54ca9d19c751df7e99467389
# 2     53699271a3a729239d203f1c
# 3     537893d3a3a7295dd332d9e0
# 4     53699d0ea3a729239d205b2e
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: open damir, dtype: object
# 0     54de1e8fc751df388646738b
# 1     54ca9d19c751df7e99467389
# 2     55095017c751df68c9882844
# 3     53699271a3a729239d203f1c
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: opendamir, dtype: object
# 0     536991b0a3a729239d203d13
# 1     536991b2a3a729239d203d1a
# 2     5cc103f906e3e7402d6fc4fc
# 3     55717121c751df588de5726c
# 4     5eded3a7c4bc16480e179ef3
# 5     5726ef67c751df48e1fcca0d
# 6     56ba2ce488ee382c284b6d5b
# 7     53699233a3a729239d203e69
# 8     536998c8a3a729239d205051
# 9     536991b0a3a729239d203d11
# 10    54f32631c751df46a0882844
# 11    54f63501c751df466f882844
# 12    54e74d51c751df375a467389
# 13    5e166f799ce2e71756a48bf2
# 14    5809e241c751df2646c562c5
# 15    54ad3c47c751df3070de6536
# 16    536991b1a3a729239d203d15
# 17    53699035a3a729239d203942
# 18    539a6f33a3a7293bc2728390
# 19    58a280c1a3a72974cbf115d7
# Name: contours départements, dtype: object
# 0     53ba4c07a3a729219b7bead3
# 1     565c615fc751df0248aad371
# 2     53699489a3a729239d204488
# 3     58b7990ba3a7293affefb38d
# 4     5c9df4b68b4c415e1d76aac6
# 5     5369945ba3a729239d204413
# 6     5c3678d59ce2e747493938ab
# 7     5b4cb383c751df4acc48b254
# 8     5b4cb052c751df44a431418a
# 9     5c37849406e3e77917e6226a
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: emissions polluantes, dtype: object
# 0     5809e241c751df2646c562c5
# 1     59f12582a3a729792d414507
# 2     536995f5a3a729239d20487f
# 3     53699233a3a729239d203e69
# 4     54ad3c47c751df3070de6536
# 5     57868e81a3a7295d371adce0
# 6     55717121c751df588de5726c
# 7     5c16d8dd634f4166797a2f7d
# 8     5808de39c751df1e0679df72
# 9     536997ffa3a729239d204e36
# 10    536998c8a3a729239d205051
# 11    545b55e1c751df52de9b6045
# 12    5e3ce3dc06e3e7184c320ba9
# 13    59591ca4a3a7291dcf9c8150
# 14    58a280c1a3a72974cbf115d7
# 15    536991b0a3a729239d203d13
# 16    5c232a54634f4135df43d418
# 17    536991b0a3a729239d203d11
# 18    580defb1a3a7292dcea9d317
# 19    536991c5a3a729239d203d4b
# Name: géofla départements, dtype: object
# 0     5369986ba3a729239d204f55
# 1     53698f4ca3a729239d2036df
# 2     58e53811c751df03df38f42d
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: effectifs police municipale, dtype: object
# 0     5a0effeac751df5832ded865
# 1     59f2031588ee380aace0cd90
# 2     5b505320c751df2603927d42
# 3     5dacf00b8b4c415af49b716f
# 4     5b0d1898c751df6efe616945
# 5     5c4ae55a634f4117716d5656
# 6     5b4f5453c751df0bb1c28757
# 7     545b55e1c751df52de9b6045
# 8     539a7245a3a7293bc272839f
# 9     59b0020ec751df07d5f13bcf
# 10    53698f50a3a729239d2036f5
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: marchés public bourgogne, dtype: object
# 0     59593619a3a7291dd09c8238
# 1     538355f9a3a72906c7ec5c5b
# 2     563dd03cb5950814b1588716
# 3     536995eda3a729239d204864
# 4     5959365ba3a7291dd09c8262
# 5     536995eca3a729239d204861
# 6     5ee28bda453a138e991e9603
# 7     563dd03ea3a729642bec3cc2
# 8     54e61cd1c751df75ad467389
# 9     59593667a3a7291dd09c826c
# 10    5b220199a3a7297ffee6cc23
# 11    59593657a3a7291dd09c825f
# 12    5dbc05756f4441755a6d57d4
# 13    5959364ba3a7291dcf9c8295
# 14    5ede432a8a0a5d2c3e77881d
# 15    5383543ea3a72906c7ec5c5a
# 16    5e6125346f444163ebeb5a59
# 17    563dd03ba3a729642bec3cbf
# 18    5369a262a3a729239d20681b
# 19    5db2a5188b4c414c3189d068
# Name: Liste gares SNCF, dtype: object
# 0     536991b0a3a729239d203d13
# 1     536991b2a3a729239d203d1a
# 2     5726ef67c751df48e1fcca0d
# 3     55717121c751df588de5726c
# 4     53699233a3a729239d203e69
# 5     536998c8a3a729239d205051
# 6     5cc103f906e3e7402d6fc4fc
# 7     5eded3a7c4bc16480e179ef3
# 8     56ba2ce488ee382c284b6d5b
# 9     5809e241c751df2646c562c5
# 10    54f32631c751df46a0882844
# 11    54ad3c47c751df3070de6536
# 12    54f63501c751df466f882844
# 13    54e74d51c751df375a467389
# 14    536991b0a3a729239d203d11
# 15    53699035a3a729239d203942
# 16    539a6f33a3a7293bc2728390
# 17    55424b64c751df766fa7b26f
# 18    57868e81a3a7295d371adce0
# 19    5808de39c751df1e0679df72
# Name: contours départements français, dtype: object
# 0     57ce8c3cc751df1a7f97bae5
# 1     5625fba688ee3820e912613c
# 2     595e006288ee3831bd5f689f
# 3     5625f82388ee38416f12613c
# 4     56a8dd2ac751df2657ceae1f
# 5     56b47f1588ee3821544b6d60
# 6     5807832bc751df174d79df72
# 7     53699ce7a3a729239d205ac3
# 8     595faf33c751df730ab78005
# 9     57559e6c88ee382aa2640390
# 10    582195e388ee387bd0c65bb3
# 11    5a05aedac751df60bef5e9f6
# 12    592e8c29c751df1f388ee89b
# 13    5a059001c751df32ef55cf4a
# 14    5c4ae55a634f4117716d5656
# 15    5ad74db988ee38033f37f23e
# 16    53698ee1a3a729239d2035bc
# 17    59cf177fb59508043ce9b853
# 18    5668697e88ee381d74af0bf4
# 19    5d8341258b4c414709e809e9
# Name: loi de finance 2016, dtype: object
# 0     5625f82388ee38416f12613c
# 1     595faf33c751df730ab78005
# 2     595254a688ee384d7843fbbf
# 3     5889d043a3a72974cbf0d5bb
# 4     53699e73a3a729239d205e9d
# 5     5495dcd4c751df6f1704805a
# 6     5756f48588ee383d11640390
# 7     574706f7c751df425b8cc4b3
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: lolf 2016, dtype: object
# 0     5e166f8006e3e76950ce8d56
# 1     5e166f7506e3e76950ce8d49
# 2     5e166f74dee7e75ddd25e8d8
# 3     5f16304a4ab12f7f44d06006
# 4     5f16304c8adcc83ea2d06005
# 5     55b23ce288ee3839da3ca28e
# 6     5f16304b1ec9cba2376dcf0c
# 7     5f123c38baaa858a72d05ffe
# 8     5b0d18ed88ee3836341f603d
# 9     5a5f4f6c88ee387da4d252a3
# 10    5ea4cfd47716d584a5c84b08
# 11    5b320fa7c751df1d7a4febae
# 12    5a1dd4e5c751df02b116a0d6
# 13    59b0020ec751df07d5f13bcf
# 14    53699edca3a729239d205fb3
# 15    53698f4ca3a729239d2036df
# 16    536c47bfa3a72933d8d1b3a6
# 17    598892dcc751df3eae8bd6ec
# 18                         NaN
# 19                         NaN
# Name: formations pas de calais, dtype: object
# 0     53698f4ca3a729239d2036df
# 1     53698e4ba3a729239d203415
# 2     53698f4da3a729239d2036ec
# 3     536997eaa3a729239d204dfd
# 4     58d49a4ba3a7293affeffb39
# 5     5e1229ee634f410816ef2ef9
# 6     53a8bd3fa3a72905b7ce5961
# 7     58ef2c61a3a7293d4ac4e179
# 8     595f09eba3a7296407d6a3a4
# 9     586db27aa3a7290df6f4bea9
# 10    5d56becc8b4c412584b830c9
# 11    5d3a7d1206e3e70553e75019
# 12    55968dedc751df26c5a453b9
# 13    5d05890406e3e72b08d1585f
# 14    5a09ada788ee3844cf133d58
# 15    55b235f988ee38213a3ca28a
# 16    59a04567c751df2e409fa755
# 17    5d325f5f9ce2e733d390b662
# 18    54291fb888ee380329a59159
# 19    5b320fa7c751df1d7a4febae
# Name: accidents de la circulation, dtype: object
# 0     53698e4ba3a729239d203415
# 1     53698f4ca3a729239d2036df
# 2     53698f4da3a729239d2036ec
# 3     58d49a4ba3a7293affeffb39
# 4     53699a1fa3a729239d2053f2
# 5     5d56becc8b4c412584b830c9
# 6     5e1229ee634f410816ef2ef9
# 7     55968dedc751df26c5a453b9
# 8     58ef2c61a3a7293d4ac4e179
# 9     5d3a7d1206e3e70553e75019
# 10    5d05890406e3e72b08d1585f
# 11    59ae106eb595087a23916974
# 12    586db27aa3a7290df6f4bea9
# 13    53a8bd3fa3a72905b7ce5961
# 14    595f09eba3a7296407d6a3a4
# 15    54291fb888ee380329a59159
# 16    59a04567c751df2e409fa755
# 17    55b235f988ee38213a3ca28a
# 18    5d325f5f9ce2e733d390b662
# 19    5530fbacc751df5ff937dddb
# Name: accidents de la route, dtype: object
# 0     5630f53b88ee385064531578
# 1     53698f4ca3a729239d2036df
# 2     53698e4ba3a729239d203415
# 3     5b320fa7c751df1d7a4febae
# 4     5a0ae958c751df2fdda1d838
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: risque de décès un an après accident, dtype: object
# 0     58c984b088ee386cdb1261f3
# 1     5808de39c751df1e0679df72
# 2     53699233a3a729239d203e69
# 3     5809e241c751df2646c562c5
# 4     5a9ac6b9c751df4caed2b133
# 5     5de8f397634f4164071119c5
# 6     536991c5a3a729239d203d4b
# 7     5878ee41a3a7291485cac7cf
# 8     5883d37688ee3810b49b8203
# 9     5cc1b94a634f4165e96436c1
# 10    5cc1b94a634f4165e96436c1
# 11    554210a9c751df2666a7b26c
# 12    5f18d3ed31eb427ec8d05ffd
# 13    5661a04088ee3863e240355f
# 14    5e9dbdbe71589194c8f7b42f
# 15    5cedcdd19ce2e74f80c3af05
# 16    5d79f02a634f4132bd8ee1c5
# 17    5e5d61e88b4c410efe6a2f26
# 18    5890bf78a3a72974c1f0dc8f
# 19    5da86e538b4c416f22a364a3
# Name: COG, dtype: object
# 0     58c984b088ee386cdb1261f3
# 1     556a0841c751df2ccfe57269
# 2     545b55e1c751df52de9b6045
# 3     5a9ac6b9c751df4caed2b133
# 4     5369995ba3a729239d205221
# 5     53699233a3a729239d203e69
# 6     536991c5a3a729239d203d4b
# 7     5809e241c751df2646c562c5
# 8     59591ca4a3a7291dcf9c8150
# 9     536998c8a3a729239d205051
# 10    5ced14688b4c4114480ce688
# 11    5661a04088ee3863e240355f
# 12    554210a9c751df2666a7b26c
# 13    536991b0a3a729239d203d13
# 14    5de8f397634f4164071119c5
# 15    54f32631c751df46a0882844
# 16    53699d0ea3a729239d205b2e
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: code officiel géographique, dtype: object
# 0     53699233a3a729239d203e69
# 1     536998c8a3a729239d205051
# 2     54f63501c751df466f882844
# 3     57868e81a3a7295d371adce0
# 4     536991b0a3a729239d203d13
# 5     536991b2a3a729239d203d1a
# 6     5883d37688ee3810b49b8203
# 7     5809e241c751df2646c562c5
# 8     56b0c2d3a3a7294d39b88a6a
# 9     5be45e9c634f413e33d36979
# 10    55424b64c751df766fa7b26f
# 11    55717121c751df588de5726c
# 12    536991b1a3a729239d203d15
# 13    545b55e1c751df52de9b6045
# 14    5808de39c751df1e0679df72
# 15    553f31fec751df67c0e96a3b
# 16    554210a9c751df2666a7b26c
# 17    54f32631c751df46a0882844
# 18    536997ffa3a729239d204e36
# 19    56ba2ce488ee382c284b6d5b
# Name: contour commune, dtype: object
# 0     53699233a3a729239d203e69
# 1     536998c8a3a729239d205051
# 2     57868e81a3a7295d371adce0
# 3     536991b0a3a729239d203d13
# 4     5883d37688ee3810b49b8203
# 5     536991b2a3a729239d203d1a
# 6     5c4aea3006e3e725ac1b2dd1
# 7     5e315daa06e3e73eeb320baf
# 8     54f63501c751df466f882844
# 9     5ed76691b967795a2dd264d1
# 10    55717121c751df588de5726c
# 11    536991b1a3a729239d203d15
# 12    55424b64c751df766fa7b26f
# 13    54f32631c751df46a0882844
# 14    536991b0a3a729239d203d11
# 15    5808de39c751df1e0679df72
# 16    5ed76691b967795a2dd264d1
# 17    553f31fec751df67c0e96a3b
# 18    554210a9c751df2666a7b26c
# 19    5c4aea3006e3e725ac1b2dd1
# Name: contours communes, dtype: object
# 0     55717121c751df588de5726c
# 1     536991b1a3a729239d203d15
# 2     55424b64c751df766fa7b26f
# 3     5ed76691b967795a2dd264d1
# 4     545b55e1c751df52de9b6045
# 5     54f32631c751df46a0882844
# 6     554210a9c751df2666a7b26c
# 7     5808de39c751df1e0679df72
# 8     553f31fec751df67c0e96a3b
# 9     536991b0a3a729239d203d11
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: contour communes, dtype: object
# 0     545b55e1c751df52de9b6045
# 1     5a9ac6b9c751df4caed2b133
# 2     59591ca4a3a7291dcf9c8150
# 3     5ced14688b4c4114480ce688
# 4     536991c5a3a729239d203d4b
# 5     536995ada3a729239d2047b3
# 6     5b7d7bac8b4c4176bfce1096
# 7     5878ee29a3a7291484cac7c9
# 8     5ed8e3e56abdf1c96b681386
# 9     5d8341258b4c414709e809e9
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: code postal, dtype: object
# 0     536991c5a3a729239d203d51
# 1     5369995ba3a729239d205221
# 2     56b0c2fdb595086d5669cb99
# 3     58c984b088ee386cdb1261f3
# 4     580a5751a3a7292dcea9d1e9
# 5     5ed8e3e56abdf1c96b681386
# 6     53699d0ea3a729239d205b2e
# 7     5624ae8ab595080b1989caa4
# 8     593aac1488ee384e8b6c4e74
# 9     5c5c3236634f4155110aa4ea
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: codes postaux, dtype: object
# 0     5bf42c958b4c4144b0110ce8
# 1     547738bcc751df6b1372f5d6
# 2     5bc35259634f41122d982759
# 3     586a824588ee3835ec3f4e61
# 4     5a6feed5a3a72976b0e5b926
# 5     5bc6dc8a8b4c411f8f1a0a17
# 6     53699949a3a729239d2051f1
# 7     5c4008ac9ce2e74195bf25b6
# 8     5ef2071bd4ffb83a3d0bb007
# 9     5e2ea5886f44417a12ee181c
# 10    5a3bb760c751df27e375554a
# 11    53699584a3a729239d20474a
# 12    5369986ea3a729239d204f65
# 13    5587ff83c751df1f16a453bd
# 14    5b89d96306e3e73e0e2ffd31
# 15    5c52d7ed634f414d531cf447
# 16    59aea788a3a72917d9f3fc77
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: prénoms, dtype: object
# 0     53ca2be2a3a7294a1ddd7847
# 1     5bb6b4f206e3e70e7a293ecd
# 2     58e53811c751df03df38f42d
# 3     5cddfddd9ce2e76d93bdb182
# 4     53698f1aa3a729239d203653
# 5     59590cf1a3a7291dcf9c7ffe
# 6     536995aba3a729239d2047ad
# 7     53d04837a3a72970fff91f17
# 8     53699fe5a3a729239d206231
# 9     5c926a7a634f410578005c68
# 10    53699ce7a3a729239d205ac3
# 11    5ae1e8ebc751df366924e95f
# 12    5ebc1ab7e5d3010d32ca8260
# 13    55b10d70c751df7e3610ccb6
# 14    5cd57bf68b4c4179299eb0e9
# 15    59b0020ec751df07d5f13bcf
# 16    53699fe4a3a729239d206227
# 17    555b616ec751df4bb2190c78
# 18                         NaN
# 19                         NaN
# Name: association, dtype: object
# 0     53698f1aa3a729239d203653
# 1     53ca2be2a3a7294a1ddd7847
# 2     58e53811c751df03df38f42d
# 3     5bb6b4f206e3e70e7a293ecd
# 4     5cddfddd9ce2e76d93bdb182
# 5     536995aba3a729239d2047ad
# 6     582c8978c751df788ec0bb7e
# 7     5ecf781de1364af7a664eb02
# 8     53ca2e62a3a7294a1ddd784b
# 9     5ae1e8ebc751df366924e95f
# 10    53699ce7a3a729239d205ac3
# 11    5c926a7a634f410578005c68
# 12    536991b2a3a729239d203d1a
# 13    5c5a8b88634f4160c7fe393d
# 14    53ba5033a3a729219b7bead9
# 15    555b616ec751df4bb2190c78
# 16    5dfa4d268b4c416bb6270186
# 17    5a7c6d10c751df4dfc94dbd2
# 18                         NaN
# 19                         NaN
# Name: associations, dtype: object
# 0     58e53811c751df03df38f42d
# 1     53ca2be2a3a7294a1ddd7847
# 2     5d36f81006e3e7531be7501d
# 3     53d04837a3a72970fff91f17
# 4     5eb2c639949dda18c97e9677
# 5     582c8978c751df788ec0bb7e
# 6     5e32231adee7e71547f5c8ee
# 7     536995aba3a729239d2047ad
# 8     5d0d24af634f411c05d9ca9b
# 9     5e166f789ce2e71756a48bf1
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: RNA, dtype: object
# 0     58e53811c751df03df38f42d
# 1     53ca2be2a3a7294a1ddd7847
# 2     5bbb5400634f41350719b01e
# 3     5d36f81006e3e7531be7501d
# 4     53698f1aa3a729239d203653
# 5     59590cf1a3a7291dcf9c7ffe
# 6     58ef2cf7a3a7293d49c4e179
# 7     53ca2e62a3a7294a1ddd784b
# 8     5dc0bc70dee7e71661936949
# 9     536995aba3a729239d2047ad
# 10    53699ce7a3a729239d205ac3
# 11    5e3221f2dee7e71333f5c8f8
# 12    5cac5d589ce2e71425bc889c
# 13    5ecf781de1364af7a664eb02
# 14    5e32231adee7e71547f5c8ee
# 15    59aea7aaa3a72917daf3fc6f
# 16    5970c858c751df537f0c5aed
# 17    5be560c89ce2e72d63831002
# 18    5b4eebcab595087c4ad496ec
# 19                         NaN
# Name: répertoire des associations, dtype: object
# 0     53699233a3a729239d203e69
# 1     5e0deb87634f410630f1d044
# 2     5dfa4d268b4c416bb6270186
# 3     5448d3e0c751df01f85d0572
# 4     5a980555b59508758f84c010
# 5     538071a9a3a7297e4d35d6ce
# 6     5be560f19ce2e72d6683100d
# 7     5369a160a3a729239d2065bc
# 8     53699569a3a729239d2046eb
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: répertoire national des associations, dtype: object
# 0     58e53811c751df03df38f42d
# 1     53ca2be2a3a7294a1ddd7847
# 2     5d36f81006e3e7531be7501d
# 3     53cdfd2ba3a7292987895b2b
# 4     53ca2e62a3a7294a1ddd784b
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: waldec, dtype: object
# 0     5c926a7a634f410578005c68
# 1     582c8978c751df788ec0bb7e
# 2     555b5673c751df4821190c78
# 3     5e6125318b4c412192d9143d
# 4     5c4ae9a206e3e725ac1b2dce
# 5     555c431bc751df5800190c78
# 6     5369993aa3a729239d2051bf
# 7     5e166f7c06e3e76950ce8d52
# 8     59591afea3a7291dd09c80fb
# 9     5bc0d6e5634f4142b4581861
# 10    537d5ad5a3a72973a2dc0278
# 11    53698ee0a3a729239d2035b8
# 12    53699058a3a729239d2039a2
# 13    58481d21c751df76c4c0bb7e
# 14    595919fea3a7291dcf9c80fc
# 15    5b7ffc618b4c4169d30727e0
# 16    5530fbacc751df5ff937dddb
# 17    5cd42a86634f4147a23df1be
# 18    5e6125316f4441640530fa22
# 19    57343feb88ee3823b0d1b934
# Name: organismes de formation, dtype: object
# 0     582c8978c751df788ec0bb7e
# 1     5e6125318b4c412192d9143d
# 2     5e166f7c06e3e76950ce8d52
# 3     5369993aa3a729239d2051bf
# 4     595918a4a3a7291dcf9c80d7
# 5     59591afda3a7291dcf9c811e
# 6     5c4ae9a206e3e725ac1b2dce
# 7     59591bcba3a7291dcf9c8139
# 8     53699058a3a729239d2039a2
# 9     58481d21c751df76c4c0bb7e
# 10    57868eeda3a7295d371add31
# 11    58595bab88ee387949c65bb3
# 12    5530fbacc751df5ff937dddb
# 13    537d5ad5a3a72973a2dc0278
# 14    595919fea3a7291dcf9c80fc
# 15    5890bf78a3a72974c1f0dc8f
# 16    58d8d8a0c751df17537c66be
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: organisme de formation, dtype: object
# 0     5ddd3cd0634f412acd60b195
# 1     5f031d2b73d414ed46d05ffd
# 2     59cc758ba3a72921191db6c4
# 3     5b12086db5950870b30303f1
# 4     5890bf78a3a72974c1f0dc8f
# 5     5369903fa3a729239d203966
# 6     5f054551211dbd0958d05ffd
# 7     59591df1a3a7291dcf9c8176
# 8     582dbacdc751df5570c0bb7e
# 9     5c3538da9ce2e7459c6d765a
# 10    5959188ea3a7291dcf9c80d4
# 11    53c26bbba3a7292df9d3196e
# 12    5369941ca3a729239d204376
# 13    53c26b06a3a7292df9d3196c
# 14    5dc423178b4c4146ca45d7ef
# 15    56b0c2edb595086d5669cb8d
# 16    53c26b08a3a7292df9d3196d
# 17    59590d21a3a7291dcf9c8026
# 18    5995685388ee383c90cb6091
# 19    5369981ba3a729239d204e7c
# Name: bibliothèques, dtype: object
# 0     5889d03fa3a72974cbf0d5b1
# 1     5c6b575b9ce2e74a605908de
# 2     5889d042a3a72974cbf0d5b8
# 3     58481d2388ee384953c65bb3
# 4     58481d2688ee384953c65bb4
# 5     53699359a3a729239d204183
# 6     536998f1a3a729239d2050d4
# 7     5be055ac634f41318d7c18b7
# 8     5889d042a3a72974c1f0d608
# 9     5e3aecb2634f4102f1094a7f
# 10    547738bcc751df6b1372f5d6
# 11    5369990aa3a729239d205126
# 12    59a0264ac751df73a78030e1
# 13    586dae71a3a7290df5f4be86
# 14    5499446fc751df6a86048068
# 15    54149eb5c751df1dc8fc95e3
# 16    5a561801c751df42d7fca9b6
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: annuaire de l'éducation, dtype: object
# 0     5c5c3236634f4155110aa4ea
# 1     5c90a4459ce2e77b2ee27c1e
# 2     5eafea7019df8efd86ded503
# 3     5c34c4d1634f4173183a64f1
# 4     53699fb3a3a729239d2061bc
# 5     5465f7fec751df09436c8d07
# 6     545b55e1c751df52de9b6045
# 7     5aec09dfc751df576c13dda8
# 8     5d1b7c576f44417a5d88e05e
# 9     5bc6cf3a9ce2e72581422d3f
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# Name: grand débat, dtype: object

# %%
import opendatascience_module as opd

# %%
all_results=[]
for i in range(len(queries)):
        results=opd.Search(queries[i],20)[0]
        all_results.append(results)

# %%
all_results
# Out:
# [['5cc8ccf8634f415c2e02a868',
#   '5b7ffc618b4c4169d30727e0',
#   '58aeede688ee38212d0209b6',
#   '56eedf1e88ee380d24908574',
#   '5971fbe588ee38522976e8f0',
#   '5ad7207ba3a7292e3ab95b2d',
#   '576b13eca3a72927ec4f8575',
#   '593457c6a3a72968e2876bf3',
#   '5883cbd788ee3810c89b81c1',
#   '56eedf15c751df4588d6e93c',
#   '558a8518c751df75e4a453c7',
#   '5a098079c751df6654626da4',
#   '5c5a6f709ce2e7579ccc53f4',
#   '5883d53d88ee3809bb9b81a6',
#   '59591e1ea3a7291dd09c8156',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '5e3221ed06e3e70507320baf',
#   '5a980555b59508758f84c010'],
#  ['5cc8ccf8634f415c2e02a868',
#   '5b7ffc618b4c4169d30727e0',
#   '58aeede688ee38212d0209b6',
#   '5ad7207ba3a7292e3ab95b2d',
#   '5971fbe588ee38522976e8f0',
#   '593457c6a3a72968e2876bf3',
#   '5bd89dba06e3e738f68c0eda',
#   '576b13e9a3a72927ec4f856f',
#   '5ca0320e9ce2e70830b50dda',
#   '5e3221ed06e3e70507320baf',
#   '576b13eda3a72927ec4f8577',
#   '576b13eca3a72927ec4f8575',
#   '5c5a6f709ce2e7579ccc53f4',
#   '5a980555b59508758f84c010',
#   '595e3ba888ee3812b934cfc7',
#   '59591e1ea3a7291dd09c8156',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '5d12ba9206e3e74672c89a4c'],
#  ['5c40066a9ce2e73bd3bf25b6',
#   '58b97cb4a3a7295fa30a2b3d',
#   '5e27c920dee7e70eee25e8d6',
#   '5a8d7833b595082dbe84c001',
#   '57092f4ea3a72944fcc6ab3e',
#   '5735a2aac751df301e8cc4b3',
#   '5e27c92106e3e73792ce8d48',
#   '5e1fe0ea06e3e76336ce8d48',
#   '5c40066806e3e75a864cc62c',
#   '58b97cb3a3a7295fa30a2b3b',
#   '5a8d7832a3a7294eaab44b85',
#   '58b97cbea3a7295fa30a2b44',
#   '5dea63a68b4c413174e64c72',
#   '5d4d618c634f4134eb32e6ef',
#   '58b69b21a3a7295a7c825103',
#   '5624b5a3a3a72928cb32aa4d',
#   '53699468a3a729239d204436',
#   '5878ee48a3a7291485cac7d7',
#   '5a355c7bc751df422970a9d1',
#   '5624ae8aa3a72922e5a9a7fd'],
#  ['5c40066a9ce2e73bd3bf25b6',
#   '58b97cb4a3a7295fa30a2b3d',
#   '5e27c920dee7e70eee25e8d6',
#   '5a8d7833b595082dbe84c001',
#   '57092f4ea3a72944fcc6ab3e',
#   '5735a2aac751df301e8cc4b3',
#   '5e27c92106e3e73792ce8d48',
#   '5e1fe0ea06e3e76336ce8d48',
#   '5c40066806e3e75a864cc62c',
#   '58b97cb3a3a7295fa30a2b3b',
#   '5a8d7832a3a7294eaab44b85',
#   '58b97cbea3a7295fa30a2b44',
#   '5d4d618c634f4134eb32e6ef',
#   '5624b5a3a3a72928cb32aa4d',
#   '58b69b21a3a7295a7c825103',
#   '5dea63a68b4c413174e64c72',
#   '53699468a3a729239d204436',
#   '5878ee48a3a7291485cac7d7',
#   '5624ae8aa3a72922e5a9a7fd',
#   '57092f4fa3a72944fcc6ab3f'],
#  ['5cc8ccf8634f415c2e02a868',
#   '58aeede688ee38212d0209b6',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '576b13eca3a72927ec4f8575',
#   '5ee0d624d915e528468166c6',
#   '576b13e9a3a72927ec4f856f',
#   '5b7ffc618b4c4169d30727e0',
#   '58aeebf688ee381d127638ef',
#   '5883cea6c751df5ab4ae0ac3',
#   '5ad7207ba3a7292e3ab95b2d',
#   '576b13e6a3a72927e94f8555',
#   '58763c02c751df57d11bc73c',
#   '58763c06c751df579b1bc73c',
#   '5d260f786f444104066d120a',
#   '576b13eda3a72927ec4f8577',
#   '5a0532c3a3a72972412468d8',
#   '5baaf1ed06e3e75e1c7347e6',
#   '5a0d115db595082e619390ff'],
#  ['5b4ca070c751df297ae95321',
#   '5dfb4b71634f417a6afdff11',
#   '5369952aa3a729239d204648',
#   '5e7734bb7f54afb898242623',
#   '5cc8ccf8634f415c2e02a868',
#   '5e9b04d8a7c5a51e029ddf47',
#   '5cce159406e3e74e33b7cfe1',
#   '5e7c5088101e50c038e30960',
#   '5369a290a3a729239d206880',
#   '5e9f971389a2ec1f27c46944',
#   '5e7bf300fb786c46feee7b6b',
#   '53699932a3a729239d20519c',
#   '5878ee5ca3a7291485cac7ea',
#   '59590d34a3a7291dd09c800e',
#   '5eab685b628daf4787eb2ade',
#   '5e74d46c696698c9cdbe9d5f',
#   '58b69b23a3a7295a7d8251b6',
#   '5ed839b64626030162179ef2',
#   '5da92b1b06e3e7517d29a306',
#   '5d9423be9ce2e70bbdecb139'],
#  ['5cc8ccf8634f415c2e02a868',
#   '5b4ca070c751df297ae95321',
#   '5dfb4b71634f417a6afdff11',
#   '5369952aa3a729239d204648',
#   '5369a290a3a729239d206880',
#   '58aeede688ee38212d0209b6',
#   '5cce159406e3e74e33b7cfe1',
#   '5e7c5088101e50c038e30960',
#   '5e9f971389a2ec1f27c46944',
#   '59590d34a3a7291dd09c800e',
#   '5e7734bb7f54afb898242623',
#   '5e9b04d8a7c5a51e029ddf47',
#   '53699932a3a729239d20519c',
#   '5878ee5ca3a7291485cac7ea',
#   '5eab685b628daf4787eb2ade',
#   '5e87cef997cf8d9b8cd1046d',
#   '5e74d46c696698c9cdbe9d5f',
#   '58b69b23a3a7295a7d8251b6',
#   '5ed839b64626030162179ef2',
#   '5e4b2f109ce2e702e3d3bb02'],
#  ['5cc8ccf8634f415c2e02a868',
#   '58aeede688ee38212d0209b6',
#   '5ccaba6a634f413ef7ec4e06',
#   '58aeebf688ee381d127638ef',
#   '5ccabbe2634f4143d3cf40e8',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '5c9358f906e3e74fc14d34c9',
#   '5d25b5e1634f417926f15701',
#   '5bb72bbc8b4c415abbff0042',
#   '5bb729698b4c4154c756e972',
#   '5bb4baa1634f417476654ea1',
#   '5c49c9f98b4c4176151deb46',
#   '5630c59488ee381814531575',
#   '5d25a4ef634f413a20c2d9f9',
#   '5ba4a9398b4c411a8d8a1df9',
#   '5c41f609634f410a76fae0b6',
#   '5e7c8529048a0a8a64d46189',
#   '5ad578cca3a7297b77b95b31'],
#  ['57868ea7a3a7295d371adcfb',
#   '5eded3a7c4bc16480e179ef3',
#   '59590d1aa3a7291dcf9c8020',
#   '5d2e688e9ce2e758a390b665',
#   '59590ceea3a7291dd09c7fd4',
#   '558974a6c751df419aa453cd',
#   '558974c488ee386f544a2307',
#   '56eed6da88ee387ccf908574',
#   '56eed986c751df3c2bd6e93b',
#   '58aadf8a88ee382dd0b5284b',
#   '56eed8f688ee38023e908575',
#   '56eed97ec751df3bc1d6e93b',
#   '56eed8e588ee38023d908574',
#   '56eed6ff88ee387cda908575',
#   '5beab6769ce2e70a3e830ff2',
#   '56eedd7fc751df4345d6e93c',
#   '56eed9c588ee38043e908575',
#   '56eedd7888ee380ad6908576',
#   '56eed92bc751df3a62d6e93b',
#   '59590d36a3a7291dd09c8010'],
#  ['5d65c64606e3e77de3d78aff',
#   '5d65c5c29ce2e74693d00586',
#   '5d65c6ee9ce2e74d1ed00585',
#   '5cc3cfae06e3e74f5d6fc4fa',
#   '5d0c8ef106e3e751d6d15860',
#   '5369a238a3a729239d2067b9',
#   '5d0c8eef06e3e751d4d158a5',
#   '5d2e65f806e3e742ffe75024',
#   '5bf1ec8f9ce2e77c4b0059c1',
#   '5d36510c9ce2e77c0c90b662',
#   '5d65c6f19ce2e74d15d00586',
#   '5d65c64706e3e77e0ed78afe',
#   '5d65c6469ce2e74941d00587',
#   '5d65c5c59ce2e74693d00587',
#   '5d65c64206e3e77de3d78afe',
#   '5cc3cf2906e3e74bd86fc4f9',
#   '5d65c6eb9ce2e74d15d00585',
#   '5cc3cf2c06e3e74bd86fc4fa',
#   '5d23de3606e3e724e2614a76',
#   '5d23de2b9ce2e76d1ef50c0d'],
#  ['536995f5a3a729239d20487f',
#   '595917bda3a7291dd09c8095',
#   '5369995ba3a729239d205221',
#   '5878ee5fa3a7291485cac7ed',
#   '5bb239f206e3e74c7a9dc60b',
#   '536990c4a3a729239d203ab1',
#   '5878ee30a3a7291484cac7d4',
#   '55717499c751df441fe5726b',
#   '53699d01a3a729239d205b0e',
#   '5eded3a7c4bc16480e179ef3',
#   '5bb239df06e3e74c779dc603',
#   '59591f14a3a7291dd09c8170',
#   '5522774288ee38028345f4fd',
#   '5522774988ee38026e45f4fe',
#   '5d1aa11a9ce2e75fcff50c0e',
#   '57868ef4a3a7295d371add39',
#   '5883cba288ee3810b49b81b1',
#   '5da11d4506e3e735ac29a305',
#   '5da11d5606e3e735ac29a306',
#   '58aef65ec751df6422045692'],
#  ['53699d01a3a729239d205b0e',
#   '5af0370db595081c1c80a892',
#   '5369986ba3a729239d204f55',
#   '53f5bd80a3a7293a0eceeccb',
#   '5e4e050406e3e745294a7149',
#   '5429753988ee380327a59166',
#   '5bec457f06e3e753e177c704',
#   '551bd693c751df24f34b1077',
#   '5489cda0c751df35a24120e7',
#   '5566c71cc751df434530056f',
#   '5bec457306e3e753e177c6f6',
#   '5bec457706e3e753e177c6fc',
#   '5bec456f06e3e753e177c6f1',
#   '5bec45699ce2e77c2e830ff6',
#   '53699d02a3a729239d205b10',
#   '5566c8b6c751df3e1f30056e',
#   '5e26bec58b4c41214c6b5da6',
#   '5bec457606e3e753e177c6fa',
#   '5bec457706e3e753e177c6fb',
#   '5bec457206e3e753e177c6f5'],
#  ['536999c0a3a729239d20530e',
#   '5878ee61a3a7291485cac7ef',
#   '5a0effeac751df5832ded865',
#   '5469f558c751df620a6c8d09',
#   '5cac3f278b4c4135ee64189f',
#   '5b6d460d8b4c4162901e4c34',
#   '5b6d44fa8b4c4161f116600e',
#   '5ca744da634f41489adbb948',
#   '5ef2069bac30aa76f6d52dd4',
#   '5cb5ec619ce2e77ac1bc8895',
#   '57868eeda3a7295d371add31',
#   '5e3e020306e3e76df3320ba9',
#   '5a980541b59508758b84c011',
#   '5e32238606e3e708e1320bb0',
#   '59345847a3a72968e2876c66',
#   '59e18d20a3a7297d21b5fb71',
#   '5dde8710634f411a198bc98b',
#   '5878ee84a3a7291485cac80f',
#   '53699ff6a3a729239d206259',
#   '59590d0ea3a7291dcf9c8016'],
#  ['59593619a3a7291dd09c8238',
#   '538355f9a3a72906c7ec5c5b',
#   '536998c0a3a729239d20503c',
#   '563dd03cb5950814b1588716',
#   '5383543ea3a72906c7ec5c5a',
#   '59593615a3a7291dcf9c8272',
#   '59593659a3a7291dcf9c82a0',
#   '59593656a3a7291dd09c825e',
#   '563dd03cb5950814b1588715',
#   '59593616a3a7291dd09c8235',
#   '53699a75a3a729239d2054c7',
#   '541010f3a3a72937cb2c7039',
#   '536995eda3a729239d204864',
#   '5959361fa3a7291dcf9c827c',
#   '5959361ca3a7291dcf9c8279',
#   '59593660a3a7291dcf9c82a6',
#   '5959365aa3a7291dcf9c82a1',
#   '5e23240a8b4c416db49b45f7',
#   '5959361da3a7291dcf9c827a',
#   '536994b5a3a729239d2044f7'],
#  ['536995f5a3a729239d20487f',
#   '5878ee38a3a7291485cac7c5',
#   '595917bda3a7291dd09c8095',
#   '5eded3a7c4bc16480e179ef3',
#   '53699f03a3a729239d206014',
#   '5878ee5fa3a7291484cac809',
#   '594b7e3fc751df7a3b52742e',
#   '55717121c751df588de5726c',
#   '5a188f3c88ee3875831dbad4',
#   '536992d0a3a729239d20400f',
#   '536992d1a3a729239d204010',
#   '57868ea7a3a7295d371adcfb',
#   '59590d1aa3a7291dcf9c8020',
#   '5369a113a3a729239d2064fd',
#   '5878ee89a3a7291485cac813',
#   '53699039a3a729239d203955',
#   '5369a161a3a729239d2065bf',
#   '53699ef4a3a729239d205fef',
#   '5ae791ac88ee386d490d3e0a',
#   '597c0ac4a3a72957e0f8370d'],
#  ['5369a18da3a729239d206626',
#   '582c3353c751df5c9cc0bb7e',
#   '5b3b474688ee387e5a6c9352',
#   '53699ce7a3a729239d205ac2',
#   '5aba684588ee381996e5a2b6',
#   '53699cd3a3a729239d205a88',
#   '53699892a3a729239d204fc9',
#   '5d10941706e3e72c96c89a5e',
#   '53698edca3a729239d2035ac',
#   '53699cdba3a729239d205a9d',
#   '53699980a3a729239d20527e',
#   '587c93d388ee380e889b81a4',
#   '53699ce6a3a729239d205ac1',
#   '57ce8c3cc751df1a7f97bae5',
#   '5e585caa06e3e778884a7149',
#   '53699981a3a729239d205282',
#   '53699898a3a729239d204fd9',
#   '53699af4a3a729239d2055f9',
#   '53699588a3a729239d204755',
#   '536998a9a3a729239d205003'],
#  ['5cc8ccf8634f415c2e02a868',
#   '5c5aa0578b4c415cfa55acfe',
#   '56050b7f88ee383f215b59ee',
#   '58aeede688ee38212d0209b6',
#   '5b4cd697b595080a07d496e0',
#   '5605163d88ee385ce95b59ee',
#   '5b6310418b4c4140e6d3db2b',
#   '5b62fed4634f410b27bbe658',
#   '56051a7988ee38595b5b59ee',
#   '5a3bb760c751df27e375554a',
#   '5605194b88ee384d085b59ee',
#   '58df25d7a3a729403c44dfe3',
#   '58b69b4fa3a7295a7c825123',
#   '53699930a3a729239d205194',
#   '5e4b630106e3e767144a7149',
#   '56a6539688ee381347822417',
#   '5df390eb634f417793e42b2f',
#   '5bffcd95634f416e16388351',
#   '5d1a128b6f44412dc873f46e',
#   '5b0f7596a3a729499a124e74'],
#  ['57dd0f2cc751df4e0879df72',
#   '5b0051f5c751df1ddd468d11',
#   '5d05890206e3e72b05d1585e',
#   '58c7a4f888ee382eb0a64d14',
#   '536997c5a3a729239d204d9e',
#   '56543049c751df2b3daad370',
#   '536997a1a3a729239d204d41',
#   '5c7d973706e3e72bfa51e155',
#   '5d0acf659ce2e75e25da144b',
#   '53699828a3a729239d204ea0',
#   '536995c7a3a729239d2047fb',
#   '5b3cfbc288ee38634b0e53c1',
#   '5c4ae9919ce2e71b15275b84',
#   '5654303788ee382b99e72046',
#   '53699057a3a729239d2039a1',
#   '59591bf9a3a7291dcf9c813f',
#   '58481d24c751df76c5c0bb7f',
#   '53698eefa3a729239d2035e4',
#   '5ec90ab739cab17f55c843e9',
#   '58a1b53388ee3875fc9b81a4'],
#  ['58d49a4ba3a7293affeffb39',
#   '5e1229ee634f410816ef2ef9',
#   '53698f4ca3a729239d2036df',
#   '536997eaa3a729239d204dfd',
#   '5d05890406e3e72b08d1585f',
#   '5d05890506e3e72b05d15861',
#   '54291fb888ee380329a59159',
#   '5d2e68839ce2e758a090b664',
#   '58ef2c61a3a7293d4ac4e179',
#   '5cddfdd506e3e7152e835f9e',
#   '540f9ed6a3a72928898af4ac',
#   '53698e4ba3a729239d203415',
#   '559691c1c751df073ca453bc',
#   '5d56becc8b4c412584b830c9',
#   '59590d4fa3a7291dd09c8022',
#   '53c26051a3a7292df9d31969',
#   '59d45f84a3a7291993b1eb6a',
#   '59d30e07a3a7291992b1eb13',
#   '59cf1a75a3a7291992b1ea0f',
#   '5baaf23a9ce2e7749d6c0db8'],
#  ['5e1229ee634f410816ef2ef9',
#   '58d49a4ba3a7293affeffb39',
#   '54291fb888ee380329a59159',
#   '53698f4ca3a729239d2036df',
#   '536997eaa3a729239d204dfd',
#   '53698e4ba3a729239d203415',
#   '55b235f388ee38213a3ca288',
#   '540f9ed6a3a72928898af4ac',
#   '55b235f988ee38213a3ca28a',
#   '559691c1c751df073ca453bc',
#   '5d2e68839ce2e758a090b664',
#   '5d05890406e3e72b08d1585f',
#   '58ef2c61a3a7293d4ac4e179',
#   '5d05890506e3e72b05d15861',
#   '53699a1fa3a729239d2053f2',
#   '59d45f84a3a7291993b1eb6a',
#   '59d30e07a3a7291992b1eb13',
#   '59cf1a75a3a7291992b1ea0f',
#   '5baaf23a9ce2e7749d6c0db8',
#   '5b935f3a9ce2e71b83bc02c2'],
#  ['56d424e688ee382a8ffa79cf',
#   '5630f53b88ee385064531578',
#   '53699a1fa3a729239d2053f3',
#   '53699a1fa3a729239d2053f2',
#   '53ba5300a3a729219b7beae1',
#   '536997eaa3a729239d204dfd',
#   '55b235f388ee38213a3ca288',
#   '55b235f988ee38213a3ca28a',
#   '53698e4ba3a729239d203415',
#   '53699a22a3a729239d2053f9',
#   '53698f4ca3a729239d2036df',
#   '5369904fa3a729239d20398b',
#   '53699a1ea3a729239d2053f0',
#   '5e80dd1227d2c24eba21b60e',
#   '53699a21a3a729239d2053f8',
#   '58d49a4ba3a7293affeffb39',
#   '59aea786a3a72917daf3fc5c',
#   '59aea7c2b595087a249169d0',
#   '59aea7c8a3a72917daf3fc7a',
#   '59aea7a6a3a72917d9f3fc84'],
#  ['5c90e1f9634f4173a63f1e79',
#   '5cc8ccf8634f415c2e02a868',
#   '58ff7313c751df382a8425cd',
#   '5c63f135634f415caf732fdd',
#   '576b13e7a3a72927ec4f856b',
#   '592c44c688ee3858997f283a',
#   '5cee7899634f413d07f9798b',
#   '5b3b474688ee387e5a6c9352',
#   '5bf368129ce2e723b40059b7',
#   '5b7fa9d28b4c416cf2d81078',
#   '58c984b088ee386cdb1261f3',
#   '59592f6aa3a7291dd09c81e0',
#   '5ca60d44634f4131c29be14d',
#   '5b3db70288ee38629c1dd2c8',
#   '58aeebf688ee381d127638ef',
#   '5ed0525ff1d43f3149179ef2',
#   '5d10bd07634f416926a98e7c',
#   '5d1aa11b06e3e70cef614a75',
#   '5c90ab42634f4150b183d170',
#   '536991b9a3a729239d203d2c'],
#  ['536990c4a3a729239d203ab1',
#   '5878ee30a3a7291484cac7d4',
#   '595915b3a3a7291dd09c8050',
#   '53699d01a3a729239d205b0e',
#   '5369995ba3a729239d205221',
#   '5878ee5fa3a7291485cac7ed',
#   '556a0841c751df2ccfe57269',
#   '58c984b088ee386cdb1261f3',
#   '598483e6c751df645afb27b3',
#   '59d45f95a3a7291993b1eb70',
#   '59cf1a88a3a7291992b1ea15',
#   '59592307a3a7291dd09c818d',
#   '5baaf27f9ce2e7749d6c0dc5',
#   '5b935f7f06e3e72a622ffd31',
#   '59d30e1bb59508043ce9b932',
#   '5661a04088ee3863e240355f',
#   '545b55e1c751df52de9b6045',
#   '5878ee41a3a7291484cac7e8',
#   '53699330a3a729239d204110',
#   '5af03706b595081c1880a8ad'],
#  ['5a09aa6588ee383d5c485dd3',
#   '5a09aa95c751df2cf9c0fac1',
#   '5a09aa8d88ee383b626c5ea7',
#   '5a09aa6d88ee383b626c5ea3',
#   '5a09aa6788ee383d5c485dd4',
#   '5a09aa6d88ee383f2f603767',
#   '5a09aa6f88ee383d65fb103b',
#   '5a09aa9188ee383b626c5ea8',
#   '5a09aa9ac751df2798e2ff33',
#   '5a09aa68c751df2416a4d7b9',
#   '59f04ed2c751df54f02c3bdb',
#   '5a09aa6f88ee383f2f603768',
#   '5a09aa85c751df2cf9c0fabe',
#   '5a09aa6dc751df2416a4d7ba',
#   '5a09aa89c751df2798e2ff30',
#   '5a09aa8bc751df2ecca46397',
#   '5bd89e7406e3e73a688c0ed4',
#   '5bd89e8006e3e73a748c0eb9',
#   '5a09aa8b88ee383d5c485dd8',
#   '5a09aa8cc751df2cf9c0fabf'],
#  ['5bd89e7406e3e73a688c0ed4',
#   '5a09aa6588ee383d5c485dd3',
#   '59f04ed2c751df54f02c3bdb',
#   '5a09aa95c751df2cf9c0fac1',
#   '5a09aa8d88ee383b626c5ea7',
#   '5a09aa6d88ee383b626c5ea3',
#   '5a09aa6f88ee383d65fb103b',
#   '5a09aa6d88ee383f2f603767',
#   '5bd89e8006e3e73a748c0eb9',
#   '5a09aa6788ee383d5c485dd4',
#   '5a09aa9ac751df2798e2ff33',
#   '5a09aa9188ee383b626c5ea8',
#   '5a09aa68c751df2416a4d7b9',
#   '5a09aa6f88ee383f2f603768',
#   '5a09aa89c751df2798e2ff30',
#   '536990c4a3a729239d203ab1',
#   '5878ee30a3a7291484cac7d4',
#   '558a854a88ee3871154a231f',
#   '5a09aa85c751df2cf9c0fabe',
#   '5bd89e7206e3e73a688c0ed1'],
#  ['5a09aa6588ee383d5c485dd3',
#   '5a09aa95c751df2cf9c0fac1',
#   '5a09aa8d88ee383b626c5ea7',
#   '5bd89e7406e3e73a688c0ed4',
#   '5a09aa6d88ee383f2f603767',
#   '5a09aa6d88ee383b626c5ea3',
#   '5a09aa6f88ee383d65fb103b',
#   '5a09aa6788ee383d5c485dd4',
#   '5a09aa9188ee383b626c5ea8',
#   '5a09aa9ac751df2798e2ff33',
#   '5a09aa68c751df2416a4d7b9',
#   '5bd89e8006e3e73a748c0eb9',
#   '5a09aa85c751df2cf9c0fabe',
#   '5a09aa6f88ee383f2f603768',
#   '5a09aa89c751df2798e2ff30',
#   '5a09aa6dc751df2416a4d7ba',
#   '5a09aa8bc751df2ecca46397',
#   '59f04ed2c751df54f02c3bdb',
#   '5a09aa8b88ee383d5c485dd8',
#   '5bd89e7206e3e73a688c0ed1'],
#  ['5af03706b595081c1880a8ad',
#   '5b7d7bac8b4c4176bfce1096',
#   '545b55e1c751df52de9b6045',
#   '596ff4b9b595082d11c49694',
#   '5ee2c654c94ae7e87b179ef3',
#   '5a9ac6b9c751df4caed2b133',
#   '593457d2a3a72968e1876c06',
#   '5ced14688b4c4114480ce688',
#   '5d64ab1c9ce2e74ed9d00586',
#   '55521287c751df7832190cb1',
#   '55520f45c751df7977190c7c',
#   '555207fcc751df7640190c79',
#   '59593c59a3a7291dcf9c82d1',
#   '5a02bf3dc751df791fd9941e',
#   '536990c4a3a729239d203ab2',
#   '555206efc751df7832190c7c',
#   '59e18c0ca3a7297d21b5fb41',
#   '536995ada3a729239d2047b3',
#   '5be560d59ce2e72d66830ff6',
#   '5cf858589ce2e750df46d420'],
#  ['5af03706b595081c1880a8ad',
#   '5b7d7bac8b4c4176bfce1096',
#   '545b55e1c751df52de9b6045',
#   '5ee2c654c94ae7e87b179ef3',
#   '5a9ac6b9c751df4caed2b133',
#   '596ff4b9b595082d11c49694',
#   '593457d2a3a72968e1876c06',
#   '5d64ab1c9ce2e74ed9d00586',
#   '59593c53a3a7291dd09c8282',
#   '5ced14688b4c4114480ce688',
#   '5a02bf3dc751df791fd9941e',
#   '536990c4a3a729239d203ab2',
#   '536995ada3a729239d2047b3',
#   '55521287c751df7832190cb1',
#   '55520f45c751df7977190c7c',
#   '555207fcc751df7640190c79',
#   '59e18c0ca3a7297d21b5fb41',
#   '5be560d59ce2e72d66830ff6',
#   '555206efc751df7832190c7c',
#   '5cf858589ce2e750df46d420'],
#  ['5cb049e08b4c412127eab7d5',
#   '53699947a3a729239d2051ea',
#   '5ef2071bd4ffb83a3d0bb007',
#   '5ca745ba634f414e82e6e31f',
#   '5369994aa3a729239d2051f2',
#   '53699949a3a729239d2051ef',
#   '53699948a3a729239d2051ed',
#   '5badedb48b4c411e64d1c736',
#   '53699949a3a729239d2051f1',
#   '5b6d43df8b4c415b1dc06963',
#   '53699946a3a729239d2051e9',
#   '5959229ca3a7291dd09c817a',
#   '5b34a5bfc751df400a122c2e',
#   '5a6feed5a3a72976b0e5b926',
#   '53699943a3a729239d2051df',
#   '59590d4ea3a7291dd09c8021',
#   '5c52d7ed634f414d531cf447',
#   '5c4008ac9ce2e74195bf25b6',
#   '5bc35259634f41122d982759',
#   '53699942a3a729239d2051dc'],
#  ['5c90e1f9634f4173a63f1e79',
#   '53a3754ea3a7297d730b2f56',
#   '55e0866ac751df32e81f92b1',
#   '59a8ea7db595086587ad72fd',
#   '5593f5e4c751df2908a453ba',
#   '5b0f75a1a3a729499a124e75',
#   '5b518e6a88ee38678aad06d6',
#   '5c63f135634f415caf732fdd',
#   '54d243f1c751df4b53467389',
#   '5bb6b4f206e3e70e7a293ecd',
#   '5d358bb48b4c414e56b57b0c',
#   '5bb6b4609ce2e77ee02456c2',
#   '59591f21a3a7291dcf9c8194',
#   '5b34a6aac751df41c9765848',
#   '5de628bb634f412a468b2ab3',
#   '5b45d48088ee382eb50f6359',
#   '59593c56a3a7291dcf9c82c9',
#   '59593c57a3a7291dcf9c82ca',
#   '5b34a9ffc751df477ef529f2',
#   '5cf8582806e3e710b1c3efec'],
#  ['5c90e1f9634f4173a63f1e79',
#   '53a3754ea3a7297d730b2f56',
#   '55e0866ac751df32e81f92b1',
#   '59a8ea7db595086587ad72fd',
#   '5593f5e4c751df2908a453ba',
#   '5b0f75a1a3a729499a124e75',
#   '5b518e6a88ee38678aad06d6',
#   '5c63f135634f415caf732fdd',
#   '54d243f1c751df4b53467389',
#   '5de628bb634f412a468b2ab3',
#   '5b45d48088ee382eb50f6359',
#   '5d358bb48b4c414e56b57b0c',
#   '59591f21a3a7291dcf9c8194',
#   '5b34a6aac751df41c9765848',
#   '5baaf5e89ce2e77a676c0dbe',
#   '5b9363169ce2e7211bbc02c6',
#   '59d30ea3b59508043de9b99a',
#   '59cf1b09b59508043ce9b875',
#   '5959237aa3a7291dcf9c8223',
#   '59d46016b59508043ce9b9e2'],
#  ['58e53811c751df03df38f42d',
#   '576b13eca3a72927e94f8561',
#   '5cc8ccf8634f415c2e02a868',
#   '5d36f81006e3e7531be7501d',
#   '576b13e9a3a72927ec4f856f',
#   '5d09b48806e3e77bc6d15859',
#   '5bd965d9634f417a3f037a54',
#   '576b13e8a3a72927ec4f856d',
#   '5e85ef0ecb702e8234f78852',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '576b13eca3a72927e94f8560',
#   '5ce8871d06e3e7647fd57eba',
#   '55c4fa31c751df183a1f92b1',
#   '5b20eb6388ee3846bf6d0787',
#   '577cc4e3c751df47c09901a0',
#   '5bf62b059ce2e77b0f0059b6',
#   '56d49e7288ee387176fa79cf',
#   '5b0f76a2a3a7294b6b124e74'],
#  ['5cc8ccf8634f415c2e02a868',
#   '58aeede688ee38212d0209b6',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '58aeebf688ee381d127638ef',
#   '5d8ae7729ce2e75ab0fe15f3',
#   '5ba4a9398b4c411a8d8a1df9',
#   '5b0f76a2a3a7294b6b124e74',
#   '56d49e7288ee387176fa79cf',
#   '58cbee4288ee3806e020f96d',
#   '5ac78a7fc751df0238f60f3d',
#   '5d09b48806e3e77bc6d15859',
#   '5c5aa0578b4c415cfa55acfe',
#   '576b13e7a3a72927ec4f856b',
#   '59593c53a3a7291dd09c8282',
#   '57271782c751df139ffcca0d',
#   '5b34a5f7c751df400a122c2f',
#   '576b13eca3a72927ec4f8575',
#   '5ce8871d06e3e7647fd57eba'],
#  ['55e0866ac751df32e81f92b1',
#   '53a3754ea3a7297d730b2f56',
#   '5593f5e4c751df2908a453ba',
#   '5c90e1f9634f4173a63f1e79',
#   '5de628bb634f412a468b2ab3',
#   '59a8ea7db595086587ad72fd',
#   '5ebf2ddbeadeb00cc2233919',
#   '5b911f12634f413f693a4192',
#   '5b4cd6d8a3a72973e1e1c343',
#   '54d243f1c751df4b53467389',
#   '5e3221f2dee7e71333f5c8f8',
#   '5c4fabf29ce2e728bb275b6d',
#   '5b45d48088ee382eb50f6359',
#   '5b0f75a1a3a729499a124e75',
#   '59591f21a3a7291dcf9c8194',
#   '5baaf5e89ce2e77a676c0dbe',
#   '5b9363169ce2e7211bbc02c6',
#   '59d30ea3b59508043de9b99a',
#   '59cf1b09b59508043ce9b875',
#   '5959237aa3a7291dcf9c8223'],
#  ['55e0866ac751df32e81f92b1',
#   '53a3754ea3a7297d730b2f56',
#   '5763f43d88ee382a64ab6512',
#   '5c90e1f9634f4173a63f1e79',
#   '5d36f81006e3e7531be7501d',
#   '58e53811c751df03df38f42d',
#   '5593f5e4c751df2908a453ba',
#   '59a8ea7db595086587ad72fd',
#   '536995d3a3a729239d20481e',
#   '5e32231adee7e71547f5c8ee',
#   '5ebf2ddbeadeb00cc2233919',
#   '5b45d48088ee382eb50f6359',
#   '5c63f135634f415caf732fdd',
#   '5de628bb634f412a468b2ab3',
#   '5a980555a3a72939a7b44ba4',
#   '5b4cd6d8a3a72973e1e1c343',
#   '5b6a6b5406e3e73bfc019080',
#   '5e3221f2dee7e71333f5c8f8',
#   '536998eea3a729239d2050ca',
#   '59593c56a3a7291dcf9c82c9'],
#  ['5cc8ccf8634f415c2e02a868',
#   '58aeede688ee38212d0209b6',
#   '58aeebf688ee381d127638ef',
#   '575fc249c751df0e29ac31a1',
#   '5c63f135634f415caf732fdd',
#   '5ba4a1998b4c410d279d68a4',
#   '5ba4a1708b4c410d1a44e797',
#   '5ba4a16a8b4c410d3557041b',
#   '5a09a702c751df2798e2ff28',
#   '5c07dff3634f4103819a273c',
#   '576b13eca3a72927ec4f8575',
#   '5593f5e4c751df2908a453ba',
#   '5b20eb6388ee3846bf6d0787',
#   '565f75a6c751df187faad376',
#   '592c61f7c751df01906abea6',
#   '5d444cf66f444162ee3f0c01',
#   '5d3ac4538b4c41615c71609a',
#   '592c6184c751df7ece1fd377',
#   '5a09a70688ee383b626c5e9c',
#   '5e15db2adee7e752bd25e8d8'],
#  ['5bec457b9ce2e77c2e83100c',
#   '5caaf23806e3e71b904eac17',
#   '582d7c02a3a7290df5f45b63',
#   '5bec456e9ce2e77c2e830ffd',
#   '5b0051f5c751df1ddd468d11',
#   '5c4ae9a206e3e725ac1b2dce',
#   '5369993aa3a729239d2051bf',
#   '5bec457c9ce2e77c2e83100d',
#   '57dd0f2cc751df4e0879df72',
#   '536990bea3a729239d203aa2',
#   '5849f40c88ee38304fc65bb3',
#   '5d0acf659ce2e75e25da144b',
#   '5c7d973706e3e72bfa51e155',
#   '5e6125318b4c412192d9143d',
#   '59593c57a3a7291dcf9c82ca',
#   '595919fea3a7291dcf9c80fc',
#   '53699884a3a729239d204fa6',
#   '5abc8054b59508653f70b8cb',
#   '59593c56a3a7291dcf9c82c9',
#   '5bec45739ce2e77c2e831004'],
#  ['5bec457b9ce2e77c2e83100c',
#   '5b0051f5c751df1ddd468d11',
#   '57dd0f2cc751df4e0879df72',
#   '5c4ae9a206e3e725ac1b2dce',
#   '5caaf23806e3e71b904eac17',
#   '582d7c02a3a7290df5f45b63',
#   '5369993aa3a729239d2051bf',
#   '53699884a3a729239d204fa6',
#   '5bec456e9ce2e77c2e830ffd',
#   '5849f40c88ee38304fc65bb3',
#   '5e6125318b4c412192d9143d',
#   '5abc8054b59508653f70b8cb',
#   '5bec457c9ce2e77c2e83100d',
#   '5d0acf659ce2e75e25da144b',
#   '5c7d973706e3e72bfa51e155',
#   '595919fea3a7291dcf9c80fc',
#   '536990bea3a729239d203aa2',
#   '59593c57a3a7291dcf9c82ca',
#   '5e166f759ce2e71756a48bed',
#   '58481d24c751df76c5c0bb7f'],
#  ['5c67b2429ce2e739005908de',
#   '5369993ca3a729239d2051c4',
#   '5ddd3cd0634f412acd60b195',
#   '58b69b34a3a7295a7c825110',
#   '5369993ba3a729239d2051c3',
#   '56b0c2fbb595086d5569cb99',
#   '59590cfca3a7291dcf9c8007',
#   '536997e7a3a729239d204df6',
#   '5959197ba3a7291dcf9c80ef',
#   '59590d20a3a7291dd09c7fff',
#   '53698e0da3a729239d20337a',
#   '5369962ca3a729239d204910',
#   '5959228ba3a7291dcf9c81db',
#   '582da8e388ee385ce8c65bb9',
#   '53c26323a3a7292df9d3196a',
#   '59590d22a3a7291dd09c8001',
#   '536997e7a3a729239d204df5',
#   '59590d48a3a7291dd09c801d',
#   '5a1d46e7c751df151abbb304',
#   '5cf8589706e3e710ecc3efea'],
#  ['5369981aa3a729239d204e7a',
#   '58a1b53388ee3875fc9b81a4',
#   '5b0051f5c751df1ddd468d11',
#   '536997d9a3a729239d204dd4',
#   '5889d043a3a72974cbf0d5ba',
#   '5bec457b9ce2e77c2e83100c',
#   '53699d56a3a729239d205be8',
#   '5889d03fa3a72974c1f0d5ff',
#   '5bec45739ce2e77c2e831004',
#   '54d4cfa1c751df0c18467389',
#   '596ff7e9a3a72957dff834ae',
#   '536998f0a3a729239d2050d1',
#   '5bec457c9ce2e77c2e83100d',
#   '5bec456e9ce2e77c2e830ffd',
#   '53699866a3a729239d204f4a',
#   '53699832a3a729239d204ec0',
#   '5d0588fb9ce2e762abda144c',
#   '5889d040a3a72974cbf0d5b3',
#   '593457cba3a72968e1876c01',
#   '5492067cc751df406e04805a'],
#  ['5eafea7019df8efd86ded503',
#   '5465f7fec751df09436c8d07',
#   '55883443c751df7991a453ba',
#   '5c90a4669ce2e77b2ee27c1f',
#   '5369921da3a729239d203e33',
#   '5c90a4459ce2e77b2ee27c1e',
#   '5c5c3236634f4155110aa4ea',
#   '5aec0c77c751df558459d453',
#   '58146bb888ee3845e113e4c7',
#   '5d19fc2f6f44410245b692ee',
#   '5369917aa3a729239d203c86',
#   '5aec0b77c751df5adf1a18fa',
#   '5aec09dfc751df576c13dda8',
#   '5c3e8e8006e3e76f0f4cc62c',
#   '57fe1446c751df182f79df72',
#   '5cc8ccf8634f415c2e02a868',
#   '5d4958299ce2e7507bfae2e2',
#   '5d49582b06e3e7763e4014a2',
#   '5e4bfb928b4c4133129f9253',
#   '5565b6c6c751df31dc5a3d4b'],
#  ['5ef20598f751d1625fbc3502',
#   '5ebf2ddbeadeb00cc2233919',
#   '53ae8c38a3a729709f56d510',
#   '5bb72ff88b4c415f21be414f',
#   '5bbf1613634f415fa9fc5807',
#   '5ef203cc514393ae9e24c756',
#   '5bb21cd6634f412c5a17030a',
#   '5caaf24d9ce2e753a68c3822',
#   '5bbdbdd606e3e719e25aef6c',
#   '5dc536cf8b4c416af002b488',
#   '5c90e1f9634f4173a63f1e79',
#   '593457cda3a72968e1876c02',
#   '5b9b6e198b4c4115e11c59ff',
#   '5469f558c751df620a6c8d09',
#   '53699930a3a729239d205194',
#   '5ca746a5634f41516aec0b48',
#   '55bb43f5c751df0e671f92b1',
#   '53699179a3a729239d203c85',
#   '59592273a3a7291dd09c8179',
#   '5959197ba3a7291dcf9c80ef']]

# %%
google_df
# Out:
#                        siren                    sirene  \
# 0   5b7ffc618b4c4169d30727e0  5b7ffc618b4c4169d30727e0
# 1   5e719db34444483bd0a1a2b9  5e719db34444483bd0a1a2b9
# 2   58ef2cfda3a7293d49c4e17a  58ef2cfda3a7293d49c4e17a
# 3   58d27679a3a7297c157fe3ae  58d27679a3a7297c157fe3ae
# 4   5c37848906e3e77914d00e71  5971fbe588ee38522976e8f0
# 5   5971fbe588ee38522976e8f0  5dd651758b4c410aeb6582e6
# 6   5dd651758b4c410aeb6582e6  5c37848906e3e77914d00e71
# 7   5369956ba3a729239d2046fc  5eed7bbeb63de854684fc1c2
# 8   5a097ae9c751df643bf1b500  5a22644f88ee3848529af925
# 9   57092f51a3a72944fcc6ab40  54f63501c751df466f882844
# 10  54f63501c751df466f882844  593457c6a3a72968e2876bf3
# 11  5530fbacc751df5ff937dddb  5530fbacc751df5ff937dddb
# 12                       NaN                       NaN
# 13                       NaN                       NaN
# 14                       NaN                       NaN
# 15                       NaN                       NaN
# 16                       NaN                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
#                  entreprises                     siret  \
# 0   5e9dbdbe71589194c8f7b42f  5b7ffc618b4c4169d30727e0
# 1   53699569a3a729239d2046eb  5e719db34444483bd0a1a2b9
# 2   5c6adbae634f4114a5c41776  5a970f31c751df6d181a6c2a
# 3   536995aba3a729239d2047ad  58ef2cfda3a7293d49c4e17a
# 4   53698f16a3a729239d203648  5e7201d522f2a43e9f736a9a
# 5   53ca2be2a3a7294a1ddd7847  58d27679a3a7297c157fe3ae
# 6   5ecf5df0eb87ae4934709e30  5971fbe588ee38522976e8f0
# 7   5ebc1ab7e5d3010d32ca8260  59591a8ca3a7291dcf9c810f
# 8   5668697e88ee381d74af0bf4  5c37848906e3e77914d00e71
# 9   5cd57bf68b4c4179299eb0e9  53699569a3a729239d2046eb
# 10                       NaN  58e70f7ba3a7294acc083ef9
# 11                       NaN  5dd651758b4c410aeb6582e6
# 12                       NaN  5369956ba3a729239d2046fc
# 13                       NaN  58b69b58a3a7295a7c825129
# 14                       NaN  559395f1c751df0f51a453b9
# 15                       NaN  5537bf2bc751df66296dd01b
# 16                       NaN                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
#                   open damir                 opendamir  \
# 0   54de1e8fc751df388646738b  54de1e8fc751df388646738b
# 1   54ca9d19c751df7e99467389  54ca9d19c751df7e99467389
# 2   53699271a3a729239d203f1c  55095017c751df68c9882844
# 3   537893d3a3a7295dd332d9e0  53699271a3a729239d203f1c
# 4   53699d0ea3a729239d205b2e                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
# 13                       NaN                       NaN
# 14                       NaN                       NaN
# 15                       NaN                       NaN
# 16                       NaN                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
#        contours départements      emissions polluantes  \
# 0   536991b0a3a729239d203d13  53ba4c07a3a729219b7bead3
# 1   536991b2a3a729239d203d1a  565c615fc751df0248aad371
# 2   5cc103f906e3e7402d6fc4fc  53699489a3a729239d204488
# 3   55717121c751df588de5726c  58b7990ba3a7293affefb38d
# 4   5eded3a7c4bc16480e179ef3  5c9df4b68b4c415e1d76aac6
# 5   5726ef67c751df48e1fcca0d  5369945ba3a729239d204413
# 6   56ba2ce488ee382c284b6d5b  5c3678d59ce2e747493938ab
# 7   53699233a3a729239d203e69  5b4cb383c751df4acc48b254
# 8   536998c8a3a729239d205051  5b4cb052c751df44a431418a
# 9   536991b0a3a729239d203d11  5c37849406e3e77917e6226a
# 10  54f32631c751df46a0882844                       NaN
# 11  54f63501c751df466f882844                       NaN
# 12  54e74d51c751df375a467389                       NaN
# 13  5e166f799ce2e71756a48bf2                       NaN
# 14  5809e241c751df2646c562c5                       NaN
# 15  54ad3c47c751df3070de6536                       NaN
# 16  536991b1a3a729239d203d15                       NaN
# 17  53699035a3a729239d203942                       NaN
# 18  539a6f33a3a7293bc2728390                       NaN
# 19  58a280c1a3a72974cbf115d7                       NaN
#
#          géofla départements effectifs police municipale  ...  \
# 0   5809e241c751df2646c562c5    5369986ba3a729239d204f55  ...
# 1   59f12582a3a729792d414507    53698f4ca3a729239d2036df  ...
# 2   536995f5a3a729239d20487f    58e53811c751df03df38f42d  ...
# 3   53699233a3a729239d203e69                         NaN  ...
# 4   54ad3c47c751df3070de6536                         NaN  ...
# 5   57868e81a3a7295d371adce0                         NaN  ...
# 6   55717121c751df588de5726c                         NaN  ...
# 7   5c16d8dd634f4166797a2f7d                         NaN  ...
# 8   5808de39c751df1e0679df72                         NaN  ...
# 9   536997ffa3a729239d204e36                         NaN  ...
# 10  536998c8a3a729239d205051                         NaN  ...
# 11  545b55e1c751df52de9b6045                         NaN  ...
# 12  5e3ce3dc06e3e7184c320ba9                         NaN  ...
# 13  59591ca4a3a7291dcf9c8150                         NaN  ...
# 14  58a280c1a3a72974cbf115d7                         NaN  ...
# 15  536991b0a3a729239d203d13                         NaN  ...
# 16  5c232a54634f4135df43d418                         NaN  ...
# 17  536991b0a3a729239d203d11                         NaN  ...
# 18  580defb1a3a7292dcea9d317                         NaN  ...
# 19  536991c5a3a729239d203d4b                         NaN  ...
#
#                          RNA                            \
# 0   58e53811c751df03df38f42d  53699041a3a729239d20396a
# 1   53ca2be2a3a7294a1ddd7847  5d13a8b6634f41070a43dff3
# 2   5d36f81006e3e7531be7501d  5a546923a3a7295c2417f21f
# 3   53d04837a3a72970fff91f17  5878ee5aa3a7291484cac804
# 4   5eb2c639949dda18c97e9677  5a944adc88ee3849d5288fb7
# 5   582c8978c751df788ec0bb7e  5c5c3236634f4155110aa4ea
# 6   5e32231adee7e71547f5c8ee  56cc6d6988ee385864fa79d0
# 7   536995aba3a729239d2047ad  5bf42c958b4c4144b0110ce8
# 8   5d0d24af634f411c05d9ca9b  5b51825fa3a72936dfe1c340
# 9   5e166f789ce2e71756a48bf1  5efa23afd85990251fc9a197
# 10                       NaN  5b598be088ee387c0c353714
# 11                       NaN  53698f4ca3a729239d2036df
# 12                       NaN  5b7ffc618b4c4169d30727e0
# 13                       NaN  5c4ae55a634f4117716d5656
# 14                       NaN  5ca1bab38b4c41179d661a7a
# 15                       NaN  5e5da8356f44412b1755a8f6
# 16                       NaN  5f1c3eca9d149439e50c740f
# 17                       NaN  54de1e8fc751df388646738b
# 18                       NaN  545b55e1c751df52de9b6045
# 19                       NaN  5e9dbdbe71589194c8f7b42f
#
#    répertoire des associations répertoire national des associations  \
# 0     58e53811c751df03df38f42d             53699233a3a729239d203e69
# 1     53ca2be2a3a7294a1ddd7847             5e0deb87634f410630f1d044
# 2     5bbb5400634f41350719b01e             5dfa4d268b4c416bb6270186
# 3     5d36f81006e3e7531be7501d             5448d3e0c751df01f85d0572
# 4     53698f1aa3a729239d203653             5a980555b59508758f84c010
# 5     59590cf1a3a7291dcf9c7ffe             538071a9a3a7297e4d35d6ce
# 6     58ef2cf7a3a7293d49c4e179             5be560f19ce2e72d6683100d
# 7     53ca2e62a3a7294a1ddd784b             5369a160a3a729239d2065bc
# 8     5dc0bc70dee7e71661936949             53699569a3a729239d2046eb
# 9     536995aba3a729239d2047ad                                  NaN
# 10    53699ce7a3a729239d205ac3                                  NaN
# 11    5e3221f2dee7e71333f5c8f8                                  NaN
# 12    5cac5d589ce2e71425bc889c                                  NaN
# 13    5ecf781de1364af7a664eb02                                  NaN
# 14    5e32231adee7e71547f5c8ee                                  NaN
# 15    59aea7aaa3a72917daf3fc6f                                  NaN
# 16    5970c858c751df537f0c5aed                                  NaN
# 17    5be560c89ce2e72d63831002                                  NaN
# 18    5b4eebcab595087c4ad496ec                                  NaN
# 19                         NaN                                  NaN
#
#                       waldec   organismes de formation  \
# 0   58e53811c751df03df38f42d  5c926a7a634f410578005c68
# 1   53ca2be2a3a7294a1ddd7847  582c8978c751df788ec0bb7e
# 2   5d36f81006e3e7531be7501d  555b5673c751df4821190c78
# 3   53cdfd2ba3a7292987895b2b  5e6125318b4c412192d9143d
# 4   53ca2e62a3a7294a1ddd784b  5c4ae9a206e3e725ac1b2dce
# 5                        NaN  555c431bc751df5800190c78
# 6                        NaN  5369993aa3a729239d2051bf
# 7                        NaN  5e166f7c06e3e76950ce8d52
# 8                        NaN  59591afea3a7291dd09c80fb
# 9                        NaN  5bc0d6e5634f4142b4581861
# 10                       NaN  537d5ad5a3a72973a2dc0278
# 11                       NaN  53698ee0a3a729239d2035b8
# 12                       NaN  53699058a3a729239d2039a2
# 13                       NaN  58481d21c751df76c4c0bb7e
# 14                       NaN  595919fea3a7291dcf9c80fc
# 15                       NaN  5b7ffc618b4c4169d30727e0
# 16                       NaN  5530fbacc751df5ff937dddb
# 17                       NaN  5cd42a86634f4147a23df1be
# 18                       NaN  5e6125316f4441640530fa22
# 19                       NaN  57343feb88ee3823b0d1b934
#
#       organisme de formation             bibliothèques  \
# 0   582c8978c751df788ec0bb7e  5ddd3cd0634f412acd60b195
# 1   5e6125318b4c412192d9143d  5f031d2b73d414ed46d05ffd
# 2   5e166f7c06e3e76950ce8d52  59cc758ba3a72921191db6c4
# 3   5369993aa3a729239d2051bf  5b12086db5950870b30303f1
# 4   595918a4a3a7291dcf9c80d7  5890bf78a3a72974c1f0dc8f
# 5   59591afda3a7291dcf9c811e  5369903fa3a729239d203966
# 6   5c4ae9a206e3e725ac1b2dce  5f054551211dbd0958d05ffd
# 7   59591bcba3a7291dcf9c8139  59591df1a3a7291dcf9c8176
# 8   53699058a3a729239d2039a2  582dbacdc751df5570c0bb7e
# 9   58481d21c751df76c4c0bb7e  5c3538da9ce2e7459c6d765a
# 10  57868eeda3a7295d371add31  5959188ea3a7291dcf9c80d4
# 11  58595bab88ee387949c65bb3  53c26bbba3a7292df9d3196e
# 12  5530fbacc751df5ff937dddb  5369941ca3a729239d204376
# 13  537d5ad5a3a72973a2dc0278  53c26b06a3a7292df9d3196c
# 14  595919fea3a7291dcf9c80fc  5dc423178b4c4146ca45d7ef
# 15  5890bf78a3a72974c1f0dc8f  56b0c2edb595086d5669cb8d
# 16  58d8d8a0c751df17537c66be  53c26b08a3a7292df9d3196d
# 17                       NaN  59590d21a3a7291dcf9c8026
# 18                       NaN  5995685388ee383c90cb6091
# 19                       NaN  5369981ba3a729239d204e7c
#
#      annuaire de l'éducation               grand débat
# 0   5889d03fa3a72974cbf0d5b1  5c5c3236634f4155110aa4ea
# 1   5c6b575b9ce2e74a605908de  5c90a4459ce2e77b2ee27c1e
# 2   5889d042a3a72974cbf0d5b8  5eafea7019df8efd86ded503
# 3   58481d2388ee384953c65bb3  5c34c4d1634f4173183a64f1
# 4   58481d2688ee384953c65bb4  53699fb3a3a729239d2061bc
# 5   53699359a3a729239d204183  5465f7fec751df09436c8d07
# 6   536998f1a3a729239d2050d4  545b55e1c751df52de9b6045
# 7   5be055ac634f41318d7c18b7  5aec09dfc751df576c13dda8
# 8   5889d042a3a72974c1f0d608  5d1b7c576f44417a5d88e05e
# 9   5e3aecb2634f4102f1094a7f  5bc6cf3a9ce2e72581422d3f
# 10  547738bcc751df6b1372f5d6                       NaN
# 11  5369990aa3a729239d205126                       NaN
# 12  59a0264ac751df73a78030e1                       NaN
# 13  586dae71a3a7290df5f4be86                       NaN
# 14  5499446fc751df6a86048068                       NaN
# 15  54149eb5c751df1dc8fc95e3                       NaN
# 16  5a561801c751df42d7fca9b6                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
# [20 rows x 39 columns]

# %%
list(google_df['siren'])
# Out:
# ['5b7ffc618b4c4169d30727e0',
#  '5e719db34444483bd0a1a2b9',
#  '58ef2cfda3a7293d49c4e17a',
#  '58d27679a3a7297c157fe3ae',
#  '5c37848906e3e77914d00e71',
#  '5971fbe588ee38522976e8f0',
#  '5dd651758b4c410aeb6582e6',
#  '5369956ba3a729239d2046fc',
#  '5a097ae9c751df643bf1b500',
#  '57092f51a3a72944fcc6ab40',
#  '54f63501c751df466f882844',
#  '5530fbacc751df5ff937dddb',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
def response_similarity(all_results, google_df):
    all_common=[]
    for i in range(len(all_results)):
        list1_as_set = set(all_results[i])
        intersection = list1_as_set.intersection(list(google_df.iloc[:,i]))
        intersection_as_list = list(intersection)
        all_common.append(intersection_as_list)
    return(all_common)

# %%
all_common=response_similarity(all_results, google_df)

# %%
nn=[]
for i in all_common:
    nn.append(len(i))

# %%
sum(nn)/len(nn)
# Out:
# 1.763157894736842

# %% [markdown]
# #### en moyenne 1.7 resultats communs sur 20 premiers resultats mais bon parfois yen pas 20 (souvent)

# %%
list1_as_set = set(all_results[0])
intersection = list1_as_set.intersection(list(google_df['siren']))
intersection_as_list = list(intersection)
print(intersection_as_list)
# Out:
# ['5971fbe588ee38522976e8f0', '5b7ffc618b4c4169d30727e0']

# %%
def first_found_pos(queries, ids):
    positions=[101]*len(queries)
    for i in range(len(queries)):
        results=opd.Search(queries[i],100)[0]
        k=0
        for r in results:
            k=k+1
            if r==ids[i]:
                positions[i]=k
    return positions

# %%
queries
# Out:
# array(['siren', 'sirene', 'entreprise', 'entreprises', 'siret',
#        'open damir', 'opendamir', 'damir', 'contours départements',
#        'emissions polluantes', 'géofla départements',
#        'effectifs police municipale', 'marchés public bourgogne',
#        'Liste gares SNCF', 'contours départements français',
#        'loi de finance 2016', 'lolf 2016', 'formations pas de calais',
#        'accidents de la circulation', 'accidents de la route',
#        'risque de décès un an après accident', 'COG',
#        'code officiel géographique', 'contour commune',
#        'contours communes', 'contour communes', 'code postal',
#        'codes postaux', 'prénoms', 'association', 'associations', 'RNA',
#        'nan', 'répertoire des associations',
#        'répertoire national des associations', 'waldec',
#        'organismes de formation', 'organisme de formation',
#        'bibliothèques', "annuaire de l'éducation", 'grand débat',
#        'vie-publique répertoire'], dtype='<U36')

# %%
POSs=first_found_pos(queries, ids)

# %%
for (i,j) in zip(POSs, queries):
    print(i,j)
# Out:
# 2 siren
# 2 sirene
# 101 entreprise
# 101 entreprises
# 9 siret
# 78 open damir
# 101 opendamir
# 101 damir
# 101 contours départements
# 32 emissions polluantes
# 1 géofla départements
# 3 effectifs police municipale
# 3 marchés public bourgogne
# 1 Liste gares SNCF
# 101 contours départements français
# 101 loi de finance 2016
# 101 lolf 2016
# 101 formations pas de calais
# 4 accidents de la circulation
# 5 accidents de la route
# 2 risque de décès un an après accident
# 11 COG
# 8 code officiel géographique
# 101 contour commune
# 101 contours communes
# 101 contour communes
# 3 code postal
# 3 codes postaux
# 89 prénoms
# 101 association
# 101 associations
# 1 RNA
# 101 nan
# 80 répertoire des associations
# 6 répertoire national des associations
# 101 waldec
# 49 organismes de formation
# 46 organisme de formation
# 101 bibliothèques
# 27 annuaire de l'éducation
# 7 grand débat
# 101 vie-publique répertoire

# %%
bench_score(queries, ids)
# Out:
# 20.657894736842106
# [1, 1, 101, 1, 101, 1, 101, 101, 16, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 1, 1, 101, 1, 101, 101, 101, 101, 101]
# 20.657894736842106

# %%
classify_results(queries, first_found_pos(queries, ids))
# Out:
# ([('siren', 1),
#   ('sirene', 1),
#   ('siret', 1),
#   ('opendamir', 1),
#   ('RNA', 1),
#   ('répertoire des associations', 1),
#   ('waldec', 1)],
#  [('entreprises', 101),
#   ('open damir', 101),
#   ('contours départements', 101),
#   ('emissions polluantes', 101),
#   ('géofla départements', 16),
#   ('effectifs police municipale', 101),
#   ('marchés public bourgogne', 101),
#   ('Liste gares SNCF', 101),
#   ('contours départements français', 101),
#   ('loi de finance 2016', 101),
#   ('lolf 2016', 101),
#   ('formations pas de calais', 101),
#   ('accidents de la circulation', 101),
#   ('accidents de la route', 101),
#   ('risque de décès un an après accident', 101),
#   ('COG', 101),
#   ('code officiel géographique', 101),
#   ('contour commune', 101),
#   ('contours communes', 101),
#   ('contour communes', 101),
#   ('code postal', 101),
#   ('codes postaux', 101),
#   ('prénoms', 101),
#   ('association', 101),
#   ('associations', 101),
#   ('répertoire national des associations', 101),
#   ('organismes de formation', 101),
#   ('organisme de formation', 101),
#   ('bibliothèques', 101),
#   ("annuaire de l'éducation", 101),
#   ('grand débat', 101)],
#  [])

# %%
def classify_results(queries, positions):
    acceptable=[]
    rejected=[]
    bof=[]
    for q in range(len(queries)):
        if positions[q]==100:
            rejected.append((queries[q], positions[q]))
        else:
            if positions[q]<=5:
                 acceptable.append((queries[q], positions[q]))
            else:
                bof.append((queries[q], positions[q]))
    return acceptable, bof, rejected

def bench_score(queries, ids):
    positions=first_found_pos(queries, ids)
    score=0
    for i in positions:
        score+=101-i
    score=score/len(queries)
    print(score)
    print(positions)
    return(score)

# %%
vecss=[1,2,3,4,5]

# %%
vecss[:-1]
# Out:
# [1, 2, 3, 4]

# %%
vecss.append(list(id2vec(get_id(48))))

# %%
n_ids, score=Search('agriculture biologique', 10)

# %%
for i in n_ids:
    print('Neighbour  ' + data_np[get_idx(i)]+ '\n')
    print(i)
# Out:
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 5baaf08306e3e75ac77347e9
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 5b935d619ce2e71929bc02c2
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 59d45f70b59508043de9ba09
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 59d30df3a3a7291993b1eae0
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 59cf1a61b59508043de9b878
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 595922eba3a7291dcf9c81df
# Neighbour  agriculture biologique productions végétales surfaces par département. agriculture agriculture biologique developpement durable occupation du sol
#
# 53699c14a3a729239d2058b4
# Neighbour  agriculture bio productions végétales surfaces par département. agriculture vie economique innovation
#
# 595916c4a3a7291dcf9c809d
# Neighbour  surfaces de cultures en agriculture biologique en corse de . ab agriculture agriculture biologique fruits grandes cultures
#
# 5beafbda9ce2e77441831002
# Neighbour  aide installation des jeunes agriculteurs années et . agriculteurs agriculture bretagne developpement durable exploitant agricole exploitation agricole
#
# 56d44af588ee3867bcfa79cf

# %%
import pandas as pd
df=pd.read_csv('../../data/querys.csv', sep=',',error_bad_lines=False, encoding='latin-1') #le fichier original

# %%
data=pd.read_pickle("../../data/nodesc_clean.pkl")
data_np=data.to_numpy()

# %%
pca_space[get_idx('53ba4c07a3a729219b7bead3')]
# Out:
# array([-1.28434331, -3.45974299, -1.69202476,  3.02181656,  5.08455115,
#        -1.23227441,  0.41482335, -1.52394594, -0.62698708, -0.88486056,
#        -1.01096387, -1.25736276, -0.67990563, -0.82565908,  0.11153779,
#         1.50026546,  1.65519552, -1.23502851,  1.79596791,  0.99266682,
#        -0.2531902 ,  1.49539908, -0.4166633 ,  0.39676161,  3.80853666,
#        -0.88179272,  0.73311649, -0.26577974, -0.89995632, -0.93473154])

# %%
df_array=np.array(df)

# %%
for i in range(len(df_array)):
    n_ids, score = Similarity(df_array[i][2], 10)
    print('\n'+df_array[i][0])
    for k in range(len(n_ids)):
        print('Neighbour n°: '+ str(k) + data_np[get_idx(n_ids[k])])
# Out:
# siren
# Neighbour n°: 0arrêté du 15 septembre délibération crpmem normandie praires et amandes oc abrog 88 . autres coquillages cantonnement crpm manche normandie
# Neighbour n°: 1maisons départementales des solidarités localisation. aide sociale mds solidarite
# Neighbour n°: 2stationnements particuliers ville de lorient. deplacements duree limitee emplacement reserve livraison lorient personne mobilite reduite pmr stationnement taxi transports ville de lorient
# Neighbour n°: 3données essentielles des marchés publics publiés sur marches publics.info aws . commande publique donnees essentielles
# Neighbour n°: 4annuaire géolocalisé. administration adresse annuaire citoyennete courriel email finances publiques gouvernement mail telephone
# Neighbour n°: 5température quotidienne régionale depuis janvier . developpement durable meteorologie region territoire territoires et regions
# Neighbour n°: 6dette propre au 1er janvier de l'exercice. budget dette propre finances departementales territoire
# Neighbour n°: 7historique de la production d'énergie en occitanie sur la période . developpement durable energie production
# Neighbour n°: 8maires des hautes pyrénées. democratie et citoyennete elus maires
# Neighbour n°: 9habillage bâti schématique. bati ilot metz metropole schematique tache urbaine
#
# sirene
# Neighbour n°: 0arrêté du 15 septembre délibération crpmem normandie praires et amandes oc abrog 88 . autres coquillages cantonnement crpm manche normandie
# Neighbour n°: 1maisons départementales des solidarités localisation. aide sociale mds solidarite
# Neighbour n°: 2stationnements particuliers ville de lorient. deplacements duree limitee emplacement reserve livraison lorient personne mobilite reduite pmr stationnement taxi transports ville de lorient
# Neighbour n°: 3données essentielles des marchés publics publiés sur marches publics.info aws . commande publique donnees essentielles
# Neighbour n°: 4annuaire géolocalisé. administration adresse annuaire citoyennete courriel email finances publiques gouvernement mail telephone
# Neighbour n°: 5température quotidienne régionale depuis janvier . developpement durable meteorologie region territoire territoires et regions
# Neighbour n°: 6dette propre au 1er janvier de l'exercice. budget dette propre finances departementales territoire
# Neighbour n°: 7historique de la production d'énergie en occitanie sur la période . developpement durable energie production
# Neighbour n°: 8maires des hautes pyrénées. democratie et citoyennete elus maires
# Neighbour n°: 9habillage bâti schématique. bati ilot metz metropole schematique tache urbaine
#
# entreprise
# Neighbour n°: 0arrêté du 15 septembre délibération crpmem normandie praires et amandes oc abrog 88 . autres coquillages cantonnement crpm manche normandie
# Neighbour n°: 1maisons départementales des solidarités localisation. aide sociale mds solidarite
# Neighbour n°: 2stationnements particuliers ville de lorient. deplacements duree limitee emplacement reserve livraison lorient personne mobilite reduite pmr stationnement taxi transports ville de lorient
# Neighbour n°: 3données essentielles des marchés publics publiés sur marches publics.info aws . commande publique donnees essentielles
# Neighbour n°: 4annuaire géolocalisé. administration adresse annuaire citoyennete courriel email finances publiques gouvernement mail telephone
# Neighbour n°: 5température quotidienne régionale depuis janvier . developpement durable meteorologie region territoire territoires et regions
# Neighbour n°: 6dette propre au 1er janvier de l'exercice. budget dette propre finances departementales territoire
# Neighbour n°: 7historique de la production d'énergie en occitanie sur la période . developpement durable energie production
# Neighbour n°: 8maires des hautes pyrénées. democratie et citoyennete elus maires
# Neighbour n°: 9habillage bâti schématique. bati ilot metz metropole schematique tache urbaine
#
# entreprises
# Neighbour n°: 0arrêté du 15 septembre délibération crpmem normandie praires et amandes oc abrog 88 . autres coquillages cantonnement crpm manche normandie
# Neighbour n°: 1maisons départementales des solidarités localisation. aide sociale mds solidarite
# Neighbour n°: 2stationnements particuliers ville de lorient. deplacements duree limitee emplacement reserve livraison lorient personne mobilite reduite pmr stationnement taxi transports ville de lorient
# Neighbour n°: 3données essentielles des marchés publics publiés sur marches publics.info aws . commande publique donnees essentielles
# Neighbour n°: 4annuaire géolocalisé. administration adresse annuaire citoyennete courriel email finances publiques gouvernement mail telephone
# Neighbour n°: 5température quotidienne régionale depuis janvier . developpement durable meteorologie region territoire territoires et regions
# Neighbour n°: 6dette propre au 1er janvier de l'exercice. budget dette propre finances departementales territoire
# Neighbour n°: 7historique de la production d'énergie en occitanie sur la période . developpement durable energie production
# Neighbour n°: 8maires des hautes pyrénées. democratie et citoyennete elus maires
# Neighbour n°: 9habillage bâti schématique. bati ilot metz metropole schematique tache urbaine
#
# siret
# Neighbour n°: 0arrêté du 15 septembre délibération crpmem normandie praires et amandes oc abrog 88 . autres coquillages cantonnement crpm manche normandie
# Neighbour n°: 1maisons départementales des solidarités localisation. aide sociale mds solidarite
# Neighbour n°: 2stationnements particuliers ville de lorient. deplacements duree limitee emplacement reserve livraison lorient personne mobilite reduite pmr stationnement taxi transports ville de lorient
# Neighbour n°: 3données essentielles des marchés publics publiés sur marches publics.info aws . commande publique donnees essentielles
# Neighbour n°: 4annuaire géolocalisé. administration adresse annuaire citoyennete courriel email finances publiques gouvernement mail telephone
# Neighbour n°: 5température quotidienne régionale depuis janvier . developpement durable meteorologie region territoire territoires et regions
# Neighbour n°: 6dette propre au 1er janvier de l'exercice. budget dette propre finances departementales territoire
# Neighbour n°: 7historique de la production d'énergie en occitanie sur la période . developpement durable energie production
# Neighbour n°: 8maires des hautes pyrénées. democratie et citoyennete elus maires
# Neighbour n°: 9habillage bâti schématique. bati ilot metz metropole schematique tache urbaine
#
# open damir
# Neighbour n°: 0bureauxvote. canton cantonales cantons electeur election election locale election nationale election presidentielle elections elections cantonales elections europeennes elections legislatives elections legislatives assemblee elections regionales legislative legislatives
# Neighbour n°: 1 04 conseil municipal de grenoble. commune grenoble
# Neighbour n°: 2logements étudiants. constructions etudiants habitat social logement logements
# Neighbour n°: 3les médecins généralistes face au paiement la performance et la coopération avec les infirmiers. infirmiers medecins generalistes paiement la performance
# Neighbour n°: 4tracés du réseau de transport ferré d'ile de france. lignes reseaux ferres transport mobilite
# Neighbour n°: 5part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 6part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 7part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 8part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
# Neighbour n°: 9part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
#
# opendamir
# Neighbour n°: 0bureauxvote. canton cantonales cantons electeur election election locale election nationale election presidentielle elections elections cantonales elections europeennes elections legislatives elections legislatives assemblee elections regionales legislative legislatives
# Neighbour n°: 1 04 conseil municipal de grenoble. commune grenoble
# Neighbour n°: 2logements étudiants. constructions etudiants habitat social logement logements
# Neighbour n°: 3les médecins généralistes face au paiement la performance et la coopération avec les infirmiers. infirmiers medecins generalistes paiement la performance
# Neighbour n°: 4tracés du réseau de transport ferré d'ile de france. lignes reseaux ferres transport mobilite
# Neighbour n°: 5part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 6part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 7part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 8part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
# Neighbour n°: 9part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
#
# damir
# Neighbour n°: 0bureauxvote. canton cantonales cantons electeur election election locale election nationale election presidentielle elections elections cantonales elections europeennes elections legislatives elections legislatives assemblee elections regionales legislative legislatives
# Neighbour n°: 1 04 conseil municipal de grenoble. commune grenoble
# Neighbour n°: 2logements étudiants. constructions etudiants habitat social logement logements
# Neighbour n°: 3les médecins généralistes face au paiement la performance et la coopération avec les infirmiers. infirmiers medecins generalistes paiement la performance
# Neighbour n°: 4tracés du réseau de transport ferré d'ile de france. lignes reseaux ferres transport mobilite
# Neighbour n°: 5part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 6part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 7part des collectivités engagées dans un open data. donnees publiques opendata transparence
# Neighbour n°: 8part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
# Neighbour n°: 9part des délibérations de la collectivité accessibles sur le portail internet. deliberations site internet transparence
# contours départements
# Neighbour n°: 0accords mets et vins. alimentation cuisine gastronomie oenologie vin
# Neighbour n°: 1contours géographiques des régions – . admin express france geospatial ign region territoires
# Neighbour n°: 2périmètres des secteurs de recrutements des collèges publics de gironde. college conseil departemental gironde limites administratives
# Neighbour n°: 3plan départemental des itinéraires de promenades et de randonnées pdipr . nan
# Neighbour n°: 4résultats du premier tour de la primaire de la belle alliance. election parti socialiste presidentielle primaire raicaux
# Neighbour n°: 5collecte des archives municipales. culture loisirs sports
# Neighbour n°: 6economie zae grand poitiers données métiers. activite activite economique donnees ouvertes economique economy passerelle inspire zones
# Neighbour n°: 7votre commerce roubaix. activites business commercant commerces developpement economique economie emploi hebergement label zero dechet magasin pme restaurant restauration
# Neighbour n°: 8gaz électricité consommation annuelle par iris orléans métropole. electricite environnement gaz iris region territoire
# Neighbour n°: 9pcet de nantes métropole dictionnaire des questions de l'évaluation. environnement pcet
#
# emissions polluantes
# Neighbour n°: 0liste des services de police accueillant du public avec géolocalisation. accueil accueil de jour accueil du public adresse coordonnees geographique fichier service geocodage point geographique police police nationale service service de police stsisi
# Neighbour n°: 1concentrations moyennes mensuelles de polluants dans l'air ambiant issues du réseau permanent de mesures automatiques sur la cinor. co concentration de polluant controle de la qualite de lair environnement geospatial mensuelle mesures no no2 o3 polluant atmospherique so2
# Neighbour n°: 2concentrations moyennes mensuelles de polluants dans l'air ambiant issues du réseau permanent de mesures automatiques sur la cinor. co concentration de polluant controle de la qualite de lair environnement geospatial mensuelle mesures no no2 o3 polluant atmospherique so2
# Neighbour n°: 3populations et territoires exposés au percentil 93.2 des concentrations moyennes annuelles en ozone sur la région corse pour l'année exp corse region . air exposition exposition des personnes aux polluants o3 ozone pollution zone de pollution potentielle
# Neighbour n°: 4indice de qualité de l'air de saint denis pour un an glissant et jusqu'au lendemain. environnement geospatial indices
# Neighbour n°: 5indices centre val de loire agglo. geospatial indice indices
# Neighbour n°: 6test. test
# Neighbour n°: 7ecoles maternelles et élémentaires ville d'orléans. amenagement du territoire batiments ecole equipements logement urbanisme
# Neighbour n°: 8le catalogue des données ouvertes. administration catalogue citoyennete donnees finances publiques gouvernement open data
# Neighbour n°: 9prévision météo corse arome. environment meteo meteofrance weather forecast
#
# géofla départements
# Neighbour n°: 0points d'intérêts avec photos projet balade . balade environnement geolocalisation photos poi urbanisme
# Neighbour n°: 1les conservatoires et écoles de musique en île de france. arts conservatoires ecoles geolocalisation musique vie culturelle
# Neighbour n°: 2prévision météo île de france arome. cadre de vie environnement geolocalisation meteo
# Neighbour n°: 3validations sur le réseau ferré : profils horaires par jour type 1er semestre . deplacements transports metro rer reseau ferre train voyageurs
# Neighbour n°: 4résultats de l'aap pass numériques. agence du numerique mission societe numerique pass numerique strategie nationale pour un numerique inclusif subventions
# Neighbour n°: 5points d'arrêts du réseau de transport 'pays d'aix mobilité' issus de la base atc . arrets atc mobilite reseau de transport tcu transport collectif
# Neighbour n°: 6deal flow des projets verts : projets notifiés et financés en . nan
# Neighbour n°: 7decoset : rejets atmosphériques d'incinération. decoset territoire traitement des dechets
# Neighbour n°: 8données relatives au fonds de solidarité mis en place dans le cadre de l'épidémie de covid 19. aides aux entreprises coronavirus covid 19 entreprise entreprise artisanales entreprises fond de solidarite pme tpe
# Neighbour n°: 9lot et garonne : bd topo® version . administration altitude aspects militaires batiments eau energie geographie hydrographie industrie information installations agricoles et aquacoles lieux de production et sites industriels lot et garonne occupation des terres occupation et usage du sol referentiels de coordonnees regions maritimes repartition de la population demographie reseaux de transport sols transport unites administratives usage des sols
#
# effectifs police municipale
# Neighbour n°: 0disciplines sportives clubs et licenciés de digne les bains. club competition equipe sport sportif
# Neighbour n°: 1espaces naturels protégés du finistère propriétés départementales. environnement geobretagne
# Neighbour n°: 2millésime  : liste des communes de la métropole et des dom existantes au 01 01 . cog communes
# Neighbour n°: 3séries annuelles issues du rapport sur l’état de la fonction publique. effectifs fonction publique
# Neighbour n°: 4villes sous vidéosurveillance. camera protection surveillance videoprotection videosurveillance
# Neighbour n°: 5elections – municipales – 1er tour – ensemble de la ville. conseil election mairie municipal resultat scrutin test description subcat tour ville vote
# Neighbour n°: 6passeport jeune – par activité et par sexe. activite jeune loisir passeport
# Neighbour n°: 7délibérations de la commune de saint molf. actes administratifs citoyennete institution decisions deliberations
# Neighbour n°: 8projets de la fondation du patrimoine. chateaux eglise fondation habitation monument historique monuments patrimoine patrimoine architectural projets
# Neighbour n°: 9liste des marchés publics depuis . achat achat public business developpement economique economie emploi fourniture marche de fournitures marche de services marche public marches de travaux pme service travaux
#
# marchés public bourgogne
# Neighbour n°: 0bornes de recharge de la communauté d'agglomération du boulonnais. bornes de recharge bornes de recharge electrique bornes electriques irve voiture voiture electrique voitures electriques
# Neighbour n°: 1marchés publics groupement de commande angers . citoyennete institution commande public marche public
# Neighbour n°: 2le processus de privatisation des aéroports de toulouse lyon et nice. nan
# Neighbour n°: 3maires des côtes d'armor. commune elu maire mairie
# Neighbour n°: 4modèle numérique de terrain bordeaux métropole . courbe de niveau topographie
# Neighbour n°: 5modèle numérique de terrain bordeaux métropole . courbe de niveau topographie
# Neighbour n°: 6réseau de collecte des eaux usées. assainissement eau assainissement eaux usees environnement urbanisme logement
# Neighbour n°: 7marchés publics angers . citoyennete institution commande public marche public
# Neighbour n°: 8livres les plus empruntés depuis dans les médiathèques de la ville d'issy les moulineaux. culture emprunt livre livres mediatheque patrimoine
# Neighbour n°: 9marchés publics ville angers . citoyennete institution commande publique marche public
#
# Liste gares SNCF
# Neighbour n°: 0signalisation permanente. description du reseau geolocalisation infrastructure signalisation sncf reseau
# Neighbour n°: 1liste des passages souterrains. description du reseau geolocalisation infrastructure passages souterrains sncf reseau
# Neighbour n°: 2liste des ponts route. description du reseau geolocalisation infrastructure pont route sncf reseau
# Neighbour n°: 3liste des lignes électrifiées. description du reseau electrification geolocalisation infrastructure lignes sncf reseau
# Neighbour n°: 4particularité d'exploitation des voies. description du reseau exploitation geolocalisation infrastructure sncf reseau voies
# Neighbour n°: 5liste des ponts rail. description du reseau geolocalisation infrastructure pont rail sncf reseau
# Neighbour n°: 6liste des chantiers. description du reseau geolocalisation infrastructure sncf reseau
# Neighbour n°: 7liste des passerelles. description du reseau geolocalisation infrastructure passerelles sncf reseau
# Neighbour n°: 8horaires prévus sur les lignes de transport en commun d'ile de france gtfs . bus gtfs horaires horaires tarifs metro rer train tramway
# Neighbour n°: 9liste des accès. acces description du reseau geolocalisation infrastructure sncf reseau
# contours départements français
# Neighbour n°: 0accords mets et vins. alimentation cuisine gastronomie oenologie vin
# Neighbour n°: 1contours géographiques des régions – . admin express france geospatial ign region territoires
# Neighbour n°: 2périmètres des secteurs de recrutements des collèges publics de gironde. college conseil departemental gironde limites administratives
# Neighbour n°: 3plan départemental des itinéraires de promenades et de randonnées pdipr . nan
# Neighbour n°: 4résultats du premier tour de la primaire de la belle alliance. election parti socialiste presidentielle primaire raicaux
# Neighbour n°: 5collecte des archives municipales. culture loisirs sports
# Neighbour n°: 6economie zae grand poitiers données métiers. activite activite economique donnees ouvertes economique economy passerelle inspire zones
# Neighbour n°: 7votre commerce roubaix. activites business commercant commerces developpement economique economie emploi hebergement label zero dechet magasin pme restaurant restauration
# Neighbour n°: 8gaz électricité consommation annuelle par iris orléans métropole. electricite environnement gaz iris region territoire
# Neighbour n°: 9pcet de nantes métropole dictionnaire des questions de l'évaluation. environnement pcet
#
# loi de finance 2016
# Neighbour n°: 0tonnages collectés de déchets verts en bretagne. boundaries bretagne collecte dechets dechets verts donnees ouvertes passerelle inspire tonnage unites administratives
# Neighbour n°: 1projet de loi de finances pour plf données du volet performance. annexes budgetaires budget de letat finances publiques loi de finances performance publique plf projet annuel de performance
# Neighbour n°: 2métiers artisanat tarn et garonne . artisanat metiers statistiques tarn et garonne
# Neighbour n°: 3exécution du budget de l'état budget des comptes d'affectation spéciale en crédits de paiement cp plr . budget budget de letat comptes daffectation speciale credits de paiement execution budgetaire finances publiques missions plr programmes projet de lois de reglement
# Neighbour n°: 4séries mensuelles nationales en données corrigées des variations saisonnières et des jours ouvrables sur les offres et demandes d'emploi août . nan
# Neighbour n°: 5parc automobile par ministère en . administration cessions destructions parcs automobiles synthese generale vehicules
# Neighbour n°: 6projet de loi de finances pour plf nomenclature opérateurs de l'état. annexes budgetaires budget de letat finances publiques loi de finances plf
# Neighbour n°: 7projet de loi de finances pour plf jaune données opérateurs établissement caractère scientifique et technique epst compte financier cofi . annexes budgetaires budget de letat finances publiques jaune budgetaire loi de finances plf
# Neighbour n°: 8projet de loi de finances pour plf comptes de concours financiers par ministère. annexes budgetaires budget de letat finances publiques loi de finances plf
# Neighbour n°: 9projet de loi de finances pour plf budget annexes ba par ministère. annexes budgetaires budget de letat finances publiques loi de finances plf
#
# lolf 2016
# Neighbour n°: 0tonnages collectés de déchets verts en bretagne. boundaries bretagne collecte dechets dechets verts donnees ouvertes passerelle inspire tonnage unites administratives
# Neighbour n°: 1projet de loi de finances pour plf données du volet performance. annexes budgetaires budget de letat finances publiques loi de finances performance publique plf projet annuel de performance
# Neighbour n°: 2métiers artisanat tarn et garonne . artisanat metiers statistiques tarn et garonne
# Neighbour n°: 3exécution du budget de l'état budget des comptes d'affectation spéciale en crédits de paiement cp plr . budget budget de letat comptes daffectation speciale credits de paiement execution budgetaire finances publiques missions plr programmes projet de lois de reglement
# Neighbour n°: 4séries mensuelles nationales en données corrigées des variations saisonnières et des jours ouvrables sur les offres et demandes d'emploi août . nan
# Neighbour n°: 5parc automobile par ministère en . administration cessions destructions parcs automobiles synthese generale vehicules
# Neighbour n°: 6projet de loi de finances pour plf nomenclature opérateurs de l'état. annexes budgetaires budget de letat finances publiques loi de finances plf
# Neighbour n°: 7projet de loi de finances pour plf jaune données opérateurs établissement caractère scientifique et technique epst compte financier cofi . annexes budgetaires budget de letat finances publiques jaune budgetaire loi de finances plf
# Neighbour n°: 8projet de loi de finances pour plf comptes de concours financiers par ministère. annexes budgetaires budget de letat finances publiques loi de finances plf
# Neighbour n°: 9projet de loi de finances pour plf budget annexes ba par ministère. annexes budgetaires budget de letat finances publiques loi de finances plf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f97657b6d415> in <module>
#       1 for i in range(len(df_array)):
# ----> 2     n_ids, score = Similarity(df_array[i][2], 10)
#       3     print('\n'+df_array[i][0])
#       4     for k in range(len(n_ids)):
#       5         print('Neighbour n°: '+ str(k) + data_np[get_idx(n_ids[k])])
#
# <ipython-input-1-19f74d0e049e> in Similarity(ids, n)
#      60
#      61 def Similarity(ids, n):
# ---> 62     n_ids, score=neighbours(id2vec(ids), n)
#      63     return(n_ids, score)
#
# <ipython-input-1-19f74d0e049e> in id2vec(ids)
#      43
#      44 def id2vec(ids):
# ---> 45     return(pca_space[get_idx(ids)])
#      46
#      47 def neighbours(vector, n):
#
# <ipython-input-1-19f74d0e049e> in get_idx(ids)
#      39
#      40 def get_idx(ids):
# ---> 41     dataset_idx=id_table.index(ids)+1
#      42     return(dataset_idx)
#      43
#
# ValueError: '53699058a3a729239d2039a3' is not in list

# %%
scores=[]
positions=[]
for i in range(len(df_array)):
    n_ids, score = Search(df_array[i][0], 20)
    #print(n_ids)
    #print(df_array[i][2])
    for k in range(len(n_ids)):
        if n_ids[k]==df_array[i][2]:
            score=1-k/len(n_ids)
            pos=k
            print('FOUND :' + str(df_array[i][0])+ ' in pos '+ str(k))
            break
        else:
            score=0
            pos=k
            if k==len(n_ids)-1:
                print('DIDNT FIND:'+str(df_array[i][0]))
    scores.append(score)
    positions.append(k)
# Out:
# DIDNT FIND:siren
# DIDNT FIND:sirene
# DIDNT FIND:entreprise
# DIDNT FIND:entreprises
# DIDNT FIND:siret
# DIDNT FIND:open damir
# DIDNT FIND:opendamir
# DIDNT FIND:damir
# FOUND :contours départements in pos 6
# DIDNT FIND:emissions polluantes
# DIDNT FIND:géofla départements
# FOUND :effectifs police municipale in pos 10
# FOUND :marchés public bourgogne in pos 2
# FOUND :Liste gares SNCF in pos 0
# DIDNT FIND:contours départements français
# FOUND :loi de finance 2016 in pos 9
# DIDNT FIND:lolf 2016
# DIDNT FIND:formations pas de calais
# DIDNT FIND:accidents de la circulation
# DIDNT FIND:accidents de la route
# FOUND :risque de décès un an après accident in pos 2
# DIDNT FIND:COG
# FOUND :code officiel géographique in pos 0
# DIDNT FIND:contour commune
# DIDNT FIND:contours communes
# DIDNT FIND:contour communes
# FOUND :code postal in pos 7
# DIDNT FIND:codes postaux
# DIDNT FIND:prénoms
# DIDNT FIND:association
# DIDNT FIND:associations
# DIDNT FIND:RNA
# DIDNT FIND:nan
# DIDNT FIND:répertoire des associations
# DIDNT FIND:répertoire national des associations
# DIDNT FIND:waldec
# DIDNT FIND:organismes de formation
# DIDNT FIND:organisme de formation
# DIDNT FIND:bibliothèques
# DIDNT FIND:annuaire de l'éducation
# FOUND :grand débat in pos 18
# DIDNT FIND:vie-publique répertoire

# %%
df
# Out:
#                                    query           params  \
# 0                                  siren              NaN
# 1                                 sirene              NaN
# 2                             entreprise              NaN
# 3                            entreprises              NaN
# 4                                  siret              NaN
# 5                             open damir              NaN
# 6                              opendamir              NaN
# 7                                  damir              NaN
# 8                  contours départements              NaN
# 9                   emissions polluantes              NaN
# 10                   géofla départements              NaN
# 11           effectifs police municipale              NaN
# 12              marchés public bourgogne              NaN
# 13                      Liste gares SNCF              NaN
# 14        contours départements français              NaN
# 15                   loi de finance 2016              NaN
# 16                             lolf 2016              NaN
# 18           accidents de la circulation              NaN
# 19                 accidents de la route              NaN
# 20  risque de décès un an après accident              NaN
# 21                                   COG              NaN
# 22            code officiel géographique              NaN
# 23                       contour commune              NaN
# 24                     contours communes              NaN
# 25                      contour communes              NaN
# 26                           code postal              NaN
# 27                         codes postaux              NaN
# 28                               prénoms              NaN
# 29                           association              NaN
# 30                          associations              NaN
# 31                                   RNA              NaN
# 32                                   NaN  tag=association
# 33           répertoire des associations              NaN
# 34  répertoire national des associations              NaN
# 35                                waldec              NaN
# 36               organismes de formation              NaN
# 37                organisme de formation              NaN
# 38                         bibliothèques              NaN
# 39               annuaire de l'éducation              NaN
# 40                           grand débat              NaN
# 41               vie-publique répertoire              NaN
#
#                     expected
# 0   5b7ffc618b4c4169d30727e0
# 1   5b7ffc618b4c4169d30727e0
# 2   5b7ffc618b4c4169d30727e0
# 3   5b7ffc618b4c4169d30727e0
# 4   5b7ffc618b4c4169d30727e0
# 5   54de1e8fc751df388646738b
# 6   54de1e8fc751df388646738b
# 7   54de1e8fc751df388646738b
# 8   536991b0a3a729239d203d13
# 9   53ba4c07a3a729219b7bead3
# 10  536995f5a3a729239d20487f
# 11  5369986ba3a729239d204f55
# 12  5a0effeac751df5832ded865
# 13  59593619a3a7291dd09c8238
# 14  536991b0a3a729239d203d13
# 15  5625fba688ee3820e912613c
# 16  5625fba688ee3820e912613c
# 18  536997eaa3a729239d204dfd
# 19  536997eaa3a729239d204dfd
# 20  5630f53b88ee385064531578
# 21  58c984b088ee386cdb1261f3
# 22  58c984b088ee386cdb1261f3
# 23  53699233a3a729239d203e69
# 24  53699233a3a729239d203e69
# 25  53699233a3a729239d203e69
# 26  545b55e1c751df52de9b6045
# 27  545b55e1c751df52de9b6045
# 28  5bf42c958b4c4144b0110ce8
# 29  58e53811c751df03df38f42d
# 30  58e53811c751df03df38f42d
# 31  58e53811c751df03df38f42d
# 32  58e53811c751df03df38f42d
# 33  58e53811c751df03df38f42d
# 34  58e53811c751df03df38f42d
# 35  58e53811c751df03df38f42d
# 36  582c8978c751df788ec0bb7e
# 37  582c8978c751df788ec0bb7e
# 38  5a4e847cb59508409d014056
# 39  5889d03fa3a72974cbf0d5b1
# 40  5c5c3236634f4155110aa4ea
# 41  53699f06a3a729239d20601c

# %%
scores
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0.94,
#  0,
#  0,
#  0.9,
#  0.98,
#  1.0,
#  0,
#  0.91,
#  0,
#  0,
#  0.55,
#  0,
#  0.98,
#  0,
#  1.0,
#  0,
#  0,
#  0,
#  0.9299999999999999,
#  0,
#  0,
#  0.61,
#  0,
#  0,
#  0,
#  0,
#  0.8,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0.8200000000000001,
#  0]

# %%
df=df.drop(17)

# %%
get_id(40989)
# Out:
# '53699489a3a729239d204488'
